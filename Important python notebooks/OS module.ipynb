# %% [markdown]
# - The __os module__ allows us to access functionality of the underlying operating system. So we can perform tasks such as: navigate the file system, obtain file information, rename files, search directory trees, fetch environment variables, and many other operations

# %%
import os # Built in function for interacting with the underlying operating system

# %%
# To check current working directory

print(os.getcwd())
# Out:
# C:\Users\User

# %%
path = r'C:\Users\User\Documents'

# %%
os.path.exists(path)
# Out:
# True

# %%
try: 
    os.chdir('\Users\User\Desktop')
except UnicodeWarning as err: 
    print('Error is {}'.format(err)) # This gives an error, to avoid it, the ring is made raw string
# Out:
#   File "<ipython-input-27-a12856a6ffd4>", line 2
#     os.chdir('\Users\User\Desktop')
#             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \UXXXXXXXX escape

# %%
# To change the current working directory
os.chdir(r'\Users\User\Desktop') # For backward slash. r'' should be placed in front of raw string to avoid unicode error

# %%
print(os.getcwd()) # The new directory is now the desktop
# Out:
# C:\Users\User\Desktop

# %%
print('\t'.join(os.listdir())) # To list files in the desktop file
# Out:
# 4K Video Downloader.lnk	app_apk	AutoRecovery save of Document1.asd.docx	business analysis links.docx	Catfish Material	cheatsheet link.docx	CLASSICS	Concise GRE materials	desktop.ini	EIS 1.JPG	ETS capture.JPG	GRE useful links.docx	GT 1.JPG	images pec	IMG_20200220_181406.jpg	IMG_20200220_181526.jpg	Microsoft Edge.lnk	Microsoft Office 2016 - www.MySoftwareFree.com	Opera Browser.lnk	Research project	Tableau course	Visual Studio Code.lnk	Web scraping	~$eatsheet link.docx	~$siness analysis links.docx	µTorrent.lnk

# %%
# To create new files in the desktop file

# %%
os.mkdir('akoko_demo') # To make new directory called akoko_demo

# %%
os.makedirs(r'shola_demo\mb_demo')

# %%
print('\t'.join(os.listdir())) # shola_demo with a sub-directory mb_demo can be has been created
# Out:
# 4K Video Downloader.lnk	app_apk	AutoRecovery save of Document1.asd.docx	business analysis links.docx	Catfish Material	cheatsheet link.docx	CLASSICS	Concise GRE materials	desktop.ini	EIS 1.JPG	ETS capture.JPG	GRE useful links.docx	GT 1.JPG	images pec	IMG_20200220_181406.jpg	IMG_20200220_181526.jpg	Microsoft Edge.lnk	Microsoft Office 2016 - www.MySoftwareFree.com	Opera Browser.lnk	Research project	shola_demo	Tableau course	Visual Studio Code.lnk	Web scraping	~$eatsheet link.docx	~$siness analysis links.docx	µTorrent.lnk

# %% [markdown]
# - makedirs() create multiple directories while mkdir() create mkdir()

# %%
os.mkdir('akoko_demo_2'), os.makedirs('shola_demo_2\mb_demo')
# Out:
# (None, None)

# %%
print('\t'.join(os.listdir()))
# Out:
# 4K Video Downloader.lnk	akoko_demo	akoko_demo_2	app_apk	AutoRecovery save of Document1.asd.docx	business analysis links.docx	Catfish Material	cheatsheet link.docx	CLASSICS	Concise GRE materials	desktop.ini	EIS 1.JPG	ETS capture.JPG	GRE useful links.docx	GT 1.JPG	images pec	IMG_20200220_181406.jpg	IMG_20200220_181526.jpg	Microsoft Edge.lnk	Microsoft Office 2016 - www.MySoftwareFree.com	Opera Browser.lnk	Research project	shola_demo	shola_demo_2	Tableau course	Visual Studio Code.lnk	Web scraping	~$eatsheet link.docx	~$siness analysis links.docx	µTorrent.lnk

# %%
# As can be seen from above, akoko_demo_2 and shola_demo_2 has been successfully created on the desktop directory

# %%
# To delete in the same vein, rmdir() and removedirs() methods would be removed

# %%
os.rmdir('akoko_demo_2'), os.removedirs('shola_demo_2\mb_demo')
# Out:
# (None, None)

# %%
print('\t'.join(os.listdir())) # Looking at the directory both files have been successfully deleted
# Out:
# 4K Video Downloader.lnk	akoko_demo	app_apk	AutoRecovery save of Document1.asd.docx	business analysis links.docx	Catfish Material	cheatsheet link.docx	CLASSICS	Concise GRE materials	desktop.ini	EIS 1.JPG	ETS capture.JPG	GRE useful links.docx	GT 1.JPG	images pec	IMG_20200220_181406.jpg	IMG_20200220_181526.jpg	Microsoft Edge.lnk	Microsoft Office 2016 - www.MySoftwareFree.com	Opera Browser.lnk	Research project	shola_demo	Tableau course	Visual Studio Code.lnk	Web scraping	~$eatsheet link.docx	~$siness analysis links.docx	µTorrent.lnk

# %% [markdown]
# __Caution__ should be exercised in using __removedirs__ in deleting multiple directories to avoid __KASALA__

# %%
# To change file name. lets use rename function to change the 'Tableau course' file to 'Tableau materials'

# %%
os.rename('Tableau course', 'Tableau materials')

# %%
print('\t'.join(os.listdir()))
# Out:
# 4K Video Downloader.lnk	akoko_demo	app_apk	AutoRecovery save of Document1.asd.docx	business analysis links.docx	Catfish Material	cheatsheet link.docx	CLASSICS	Concise GRE materials	desktop.ini	EIS 1.JPG	ETS capture.JPG	GRE useful links.docx	GT 1.JPG	images pec	IMG_20200220_181406.jpg	IMG_20200220_181526.jpg	Microsoft Edge.lnk	Microsoft Office 2016 - www.MySoftwareFree.com	Opera Browser.lnk	Research project	shola_demo	Tableau materials	Visual Studio Code.lnk	Web scraping	~$eatsheet link.docx	~$siness analysis links.docx	µTorrent.lnk

# %% [markdown]
# - To get the statistics of the file

# %%
os.stat('Tableau materials')
# Out:
# os.stat_result(st_mode=16895, st_ino=3377699720632665, st_dev=3601464616, st_nlink=1, st_uid=0, st_gid=0, st_size=4096, st_atime=1587082408, st_mtime=1587082408, st_ctime=1586452522)

# %%
os.stat('Tableau materials').st_size  # To print the size of file in bytes
# Out:
# 4096

# %%
from datetime import datetime

# %%
os.stat('Tableau materials').st_mtime # To print last modified time of file usually in timestamp and non-human readable
# Out:
# 1587082408.2981546

# %%
# To make it readable

# %%
mod_time = os.stat('Tableau materials').st_mtime

# %%
print(datetime.fromtimestamp(mod_time)) # To get the human readable form of the timestamp
# Out:
# 2020-04-17 08:13:28.298155

# %%
# To get the entire route path of a directory. os.walk() method is used

for dirpath, dirname, filename in os.walk(r'\Users\User\Desktop'):
    print('directory_path', dirpath)
    print('directory_name', dirname)
    print('file_name', filename)
    print() # To create a new line within each iteration
# Out:
# directory_path \Users\User\Desktop
# directory_name ['akoko_demo', 'app_apk', 'Catfish Material', 'CLASSICS', 'Concise GRE materials', 'images pec', 'Microsoft Office 2016 - www.MySoftwareFree.com', 'Research project', 'shola_demo', 'Tableau materials', 'Web scraping']
# file_name ['4K Video Downloader.lnk', 'AutoRecovery save of Document1.asd.docx', 'business analysis links.docx', 'cheatsheet link.docx', 'desktop.ini', 'EIS 1.JPG', 'ETS capture.JPG', 'GRE useful links.docx', 'GT 1.JPG', 'IMG_20200220_181406.jpg', 'IMG_20200220_181526.jpg', 'Microsoft Edge.lnk', 'Opera Browser.lnk', 'Visual Studio Code.lnk', '~$eatsheet link.docx', '~$siness analysis links.docx', 'µTorrent.lnk']
#
# directory_path \Users\User\Desktop\akoko_demo
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\app_apk
# directory_name ['OriginPro 2018 SR1 b9.5.1.195']
# file_name []
#
# directory_path \Users\User\Desktop\app_apk\OriginPro 2018 SR1 b9.5.1.195
# directory_name []
# file_name ['Origin2018Sr1H_Downloadly.ir.iso']
#
# directory_path \Users\User\Desktop\Catfish Material
# directory_name []
# file_name ['catfish africa.pdf', 'Catfish USA material.pdf', 'CATFISH_FARMERS_HANDBOOK.pdf', 'FAO catfish hatchery Nigeria.pdf', 'PHD material Catfish.pdf']
#
# directory_path \Users\User\Desktop\CLASSICS
# directory_name []
# file_name ['BeingAndNothingness_Sartre.pdf', 'beyond-good-and-evil.pdf', 'dewey and marxist idea.pdf', 'History of Western Philosophy.pdf', 'Liberalism and social action DEWEY.pdf', 'the-problems-of-philosophy-bertrand-russell.pdf', 'Tractacus 2.pdf', 'Treatise of human nature.pdf', 'Wittgenstein-Tractatus.pdf']
#
# directory_path \Users\User\Desktop\Concise GRE materials
# directory_name ['Manhattan materials', 'MB GRE folder', 'Stopss']
# file_name ['Educational Testing Service - Official GRE Super Power Pack-Educational Testing Service (2017).pdf', 'Kaplan-Test-Prep_-coll.pdf', 'MB GRE folder-20200201T131749Z-001.zip', 'MOCK TEST.xlsx']
#
# directory_path \Users\User\Desktop\Concise GRE materials\Manhattan materials
# directory_name ['epub files', 'pdf files']
# file_name []
#
# directory_path \Users\User\Desktop\Concise GRE materials\Manhattan materials\epub files
# directory_name []
# file_name ['500 GRE Math Flash Cards.epub', 'Algebra Strategy Guide.epub', 'GRE Fractions, Decimals, & Percents.epub', 'GRE Geometry.epub', 'GRE Math Strategies 2018.epub', 'GRE Number Properties.epub', 'GRE Prep by Magoosh.epub', 'GRE Quantitative Comparisons & Data Interpretation.epub', 'GRE Reading Comprehension & Essays.epub', 'GRE Text Completion & Sentence Equivalence.epub', 'GRE Word Problems.epub']
#
# directory_path \Users\User\Desktop\Concise GRE materials\Manhattan materials\pdf files
# directory_name ['The 8 mamba']
# file_name ['5 Lb. Book of Gre Practice Problems_ 1,800+ Practice Problems in Book and Online.pdf', '500 GRE Math Flash Cards.pdf', 'GRE Math Strategies 2018.pdf', 'GRE Prep by Magoosh.pdf', 'GRE Verbal Strategies 2018.pdf']
#
# directory_path \Users\User\Desktop\Concise GRE materials\Manhattan materials\pdf files\The 8 mamba
# directory_name []
# file_name ['Algebra Strategy Guide.pdf', 'GRE Fractions Decimals Percents.pdf', 'GRE Geometry.pdf', 'GRE Number Properties.pdf', 'GRE Reading Comprehension Essays.pdf', 'GRE Text Completion Sentence Equivalence.pdf', 'GRE Word Problems.pdf']
#
# directory_path \Users\User\Desktop\Concise GRE materials\MB GRE folder
# directory_name []
# file_name ['CopyofGREArgumentTopics.pdf', 'CopyofGREIssueTopics.pdf', 'Reading Comprehension Practice (Laganjeeth Pradhan).pdf', 'VAI-S5203.pdf']
#
# directory_path \Users\User\Desktop\Concise GRE materials\Stopss
# directory_name ['New folder']
# file_name []
#
# directory_path \Users\User\Desktop\Concise GRE materials\Stopss\New folder
# directory_name ['New folder']
# file_name []
#
# directory_path \Users\User\Desktop\Concise GRE materials\Stopss\New folder\New folder
# directory_name ['Hottie']
# file_name []
#
# directory_path \Users\User\Desktop\Concise GRE materials\Stopss\New folder\New folder\Hottie
# directory_name ['Consumed By Desire Bellesa', 'No Going Back Bellesa']
# file_name ['Alexa Grace.mp4', 'Angela White.mp4', 'Aria Lee.mp4', 'Eliza Ibarra - Hot & Bothered.mp4', 'Elsa Jean.mp4', 'Gianna Dior, Gia Derza - Hot & Bothered.mp4', 'Gina Valentina.mp4', 'Honey Gold, Chanell Heart.mp4', 'Jillian Janson - Hot & Bothered.mp4', 'Karla Kush - Hot & Bothered.mp4', 'Kenna James.mp4', 'Rules Are Meant To Be Broken.mp4', 'Valentina Nappi.mp4']
#
# directory_path \Users\User\Desktop\Concise GRE materials\Stopss\New folder\New folder\Hottie\Consumed By Desire Bellesa
# directory_name []
# file_name ['Evelyn Claire.MP4', 'Lacy Lennon.mp4', 'Riley Reyes.MP4', 'Scarlit Scandal, Piper Cooper.mp4']
#
# directory_path \Users\User\Desktop\Concise GRE materials\Stopss\New folder\New folder\Hottie\No Going Back Bellesa
# directory_name []
# file_name ['No Going Back.mp4', 'Torrent Downloaded From ProstyleX.org.nfo']
#
# directory_path \Users\User\Desktop\images pec
# directory_name []
# file_name ['IMG_20181013_123723.jpg', 'IMG_20200128_173647.jpg', 'IMG_20200128_173813.jpg']
#
# directory_path \Users\User\Desktop\Microsoft Office 2016 - www.MySoftwareFree.com
# directory_name ['Software Files']
# file_name ['How to install.url', 'MySoftwareFree.com.url']
#
# directory_path \Users\User\Desktop\Microsoft Office 2016 - www.MySoftwareFree.com\Software Files
# directory_name []
# file_name ['MySoftwareFree.com.url']
#
# directory_path \Users\User\Desktop\Research project
# directory_name ['29-11-19 UV-vis', 'Confirmation report', 'koko dont delete', 'koko EIS', 'New folder', 'PL 2hrs', 'Plotted data']
# file_name ['Confirmation presentation.pptx', 'confirmation report 1.docx', 'dr_chang 1%Bi 2h and 45min.pptx', 'EIS and bode plot.pptx', 'EIS circuit 1 jpg.png', 'EIS circuit 1 word.docx', 'Excel PAPER.xlsx', 'Gantt chart PSS.pdf', 'Gantt chart.docx', 'Length and weight.pptx', 'New confirmation report 1.docx', 'New confirmation report 122.docx', 'New confirmation report 122.pdf', 'New confirmation report.docx', 'new confirmation slide 1.docx.pptx', 'new confirmation slide 1.pdf', 'Paper plots.pptx', 'PAPER.docx', 'plagiarism.pdf', 'plagiarism.pdf.docx', 'Presentation1.pptx', 'presentation_prep slide.pptx', 'Recommendation answer sheet.docx', 'Recommendation answer sheet.pdf', 'Recommendation implementation.docx', 'Result table PEC.docx', 'Results for 2hrs and 45mins growth.pptx', 'TEM result.pptx', 'Updated with 1.5 and 2.5%Bi 2h.pptx', '~$dr_chang 1%Bi 2h and 45min.pptx', '~$EIS and bode plot.pptx', '~$nfirmation report 1.docx', '~$Paper plots.pptx', '~$PAPER.docx', '~$sult table PEC.docx', '~$w confirmation report 122.docx', '~$w confirmation report.docx', '~WRL1694.tmp', '~WRL2163.tmp', '~WRL2701.tmp']
#
# directory_path \Users\User\Desktop\Research project\29-11-19 UV-vis
# directory_name []
# file_name ['4% and 5% Bi.BSW', '4% and 5% Bi.csv', 'blank.DSW']
#
# directory_path \Users\User\Desktop\Research project\Confirmation report
# directory_name ['Past slides before 26-10-19']
# file_name ['Absorbance data.xlsx', 'addings.pptx', "BABY KOKO'S WORK.docx", 'CHAPTER  2.docx', 'CHAPTER  2.pdf', 'CHAPTER 2.docx', 'Confirmation presentation.pdf', 'confirmation report 1.docx', 'confirmation report.docx', 'confirmation report.pdf', 'confirmation report.pdf.docx', 'New CA results for ZnO.pptx', 'References.docx', 'Results for 2hrs and 45mins growth.pptx', 'Results for 2hrs growth.pptx', 'Results_prep_slides.pptx', "Speaker's profile & Abstract.docx", 'Table for photocurrents.docx', 'ZnO UV-vis.xlsx', '~$APTER 2.docx', '~$Doping and photostability slides.pptx', '~$nfirmation report 1.docx', '~WRL1804.tmp']
#
# directory_path \Users\User\Desktop\Research project\Confirmation report\Past slides before 26-10-19
# directory_name []
# file_name ['CA_to_drchang.pptx', 'Confirmation presentation.pptx', 'Doping and photostability issues slide.pptx', 'Doping and photostability slides.pptx', 'FESEM and UV-vis data 22-10-19.pptx', 'Presentation1.pptx', 'Presentation2.pptx', 'Presentation3.pptx', 'Result slides [Autosaved].pptx', 'Result slides.pptx', 'technician.pptx', 'to_drchang_PECdata.pptx']
#
# directory_path \Users\User\Desktop\Research project\koko dont delete
# directory_name []
# file_name ['45 min and 2 h ZnO 1%.csv', 'blank.DSW']
#
# directory_path \Users\User\Desktop\Research project\koko EIS
# directory_name ['2019-06-04', '2019-06-10', '2019-06-16', '2019-06-20', '2019-06-24', '2019-06-26 CA 1hr and 30days later', '2019-06-27', '2019-06-28', '2019-07-12', '2019-08-23', '2019-08-27', '2019-09-08', '2019-10-26', '2019-11-02', '2019-11-04', '2019-11-16', '2019-11-27', '2019-5-16', '2020-01-19', '2020-01-26', '2020-02-19', '2020-03-07', 'April samples', 'hakim UV-vis', 'PEC data', 'ZnO Bi~1per']
# file_name ['Doping and photostability issues slide.pptx', 'Result slides.pptx', 'ZnO Bi Au bad data.pptx', 'ZnO CA AM1.5.bin', 'ZnO CA AM1.5.csv', 'ZnO CA UVcut.bin', 'ZnO Imp AM1.5.bin', 'ZnO Imp AM1.5.csv', 'ZnO Imp Dark.bin', 'ZnO Imp Dark.csv', 'ZnO Imp UVcut.bin', 'ZnO Imp UVcut.csv', 'ZnO LSV AM1.5.bin', 'ZnO LSV Dark.bin', 'ZnO LSV Dark.csv', 'ZnO LSV UVcut.bin', 'ZnO-Bi~3per CA AM1.5.bin', 'ZnO-Bi~3per CA AM1.5.csv', 'ZnO-Bi~3per CA UV.bin', 'ZnO-Bi~3per CA UV.csv', 'ZnO-Bi~3per CA UVcut.bin', 'ZnO-Bi~3per CA UVcut.csv', 'ZnO-Bi~3per Imp AM1.5.bin', 'ZnO-Bi~3per Imp AM1.5.csv', 'ZnO-Bi~3per Imp Dark.bin', 'ZnO-Bi~3per Imp Dark.csv', 'ZnO-Bi~3per Imp UV.bin', 'ZnO-Bi~3per Imp UV.csv', 'ZnO-Bi~3per Imp UVcut.bin', 'ZnO-Bi~3per Imp UVcut.csv', 'ZnO-Bi~3per LSV AM1.5.bin', 'ZnO-Bi~3per LSV AM1.5.csv', 'ZnO-Bi~3per LSV Dark.bin', 'ZnO-Bi~3per LSV Dark.csv', 'ZnO-Bi~3per LSV UV.bin', 'ZnO-Bi~3per LSV UV.csv', 'ZnO-Bi~3per LSV UVcut.bin', 'ZnO-Bi~3per LSV UVcut.csv', 'ZnO-Bi~3per Sta AM1.5.bin', 'ZnO-Bi~3per Sta AM1.5.csv', 'ZnO-Bi~3per Sta UV.bin', 'ZnO-Bi~3per Sta UV.csv', 'ZnO-Bi~3per Sta UVcut.bin', 'ZnO-Bi~3per Sta UVcut.csv', 'ZnO-Bi~L CA AM1.5.bin', 'ZnO-Bi~L CA AM1.5.csv', 'ZnO-Bi~L CA UVcut.bin', 'ZnO-Bi~L CA UVcut.csv', 'ZnO-Bi~L Imp AM1.5.bin', 'ZnO-Bi~L Imp AM1.5.csv', 'ZnO-Bi~L Imp UVcut.bin', 'ZnO-Bi~L Imp UVcut.csv', 'ZnO-Bi~L LSV UVcut.bin', 'ZnO-Bi~L LSV UVcut.csv', 'ZTO.pptx']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-06-04
# directory_name []
# file_name ['ZnO CA chop 1 visible.csv', 'ZnO CA chop 2 visible.bin', 'ZnO CA chop 2 visible.csv', 'ZnO CA chop AM1.5G.bin', 'zno ca chop am1.5g.csv', 'ZnO CA chop real 2 visible.bin', 'zno ca chop real 2 visible.csv', 'ZnO CA chop real visible- 2.bin', 'zno ca chop real visible- 2.csv', 'ZnO CA chop UV.bin', 'zno ca chop uv.csv', 'zno ca stability 2 visible.csv', 'ZnO CA stability AM1.5G.bin', 'zno ca stability am1.5g.csv', 'ZnO CA stability real visible-2.bin', 'zno ca stability real visible-2.csv', 'ZnO CA stability real visible.bin', 'zno ca stability real visible.csv', 'ZnO CA stability UV.bin', 'zno ca stability uv.csv', 'ZnO CA stability visible.bin', 'zno ca stability visible.csv', 'ZnO imp AM1.5G.bin', 'zno imp am1.5g.csv', 'ZnO imp dark 2.csv', 'ZnO imp dark.csv', 'ZnO imp real dark.bin', 'ZnO imp real dark.csv', 'ZnO imp real visible-2.bin', 'zno imp real visible-2.csv', 'ZnO imp real visible.bin', 'zno imp real visible.csv', 'ZnO imp UV.bin', 'zno imp uv.csv', 'ZnO LSV AM1.5G.bin', 'zno lsv am1.5g.csv', 'ZnO LSV dark.bin', 'ZnO LSV dark.csv', 'ZnO LSV real visible- 2.bin', 'zno lsv real visible- 2.csv', 'ZnO LSV UV.bin', 'zno lsv uv.csv', 'ZnO LSV visible.bin', 'zno lsv visible.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-06-10
# directory_name []
# file_name ['ZnO  5%Bi CA chop AM1.5.bin', 'zno  5%bi ca chop am1.5.csv', 'ZnO  5%Bi CA chop UV.bin', 'zno  5%bi ca chop uv.csv', 'ZnO  5%Bi CA chop visible.bin', 'zno  5%bi ca chop visible.csv', 'ZnO  5%Bi CA stability AM1.5.bin', 'zno  5%bi ca stability am1.5.csv', 'ZnO  5%Bi CA stability UV.bin', 'zno  5%bi ca stability uv.csv', 'ZnO  5%Bi CA stability visible.bin', 'zno  5%bi ca stability visible.csv', 'ZnO 5%Bi imp AM1.5.bin', 'zno 5%bi imp am1.5.csv', 'ZnO 5%Bi imp dark.bin', 'zno 5%bi imp dark.csv', 'ZnO 5%Bi imp UV.bin', 'zno 5%bi imp uv.csv', 'ZnO 5%Bi imp visible.bin', 'zno 5%bi imp visible.csv', 'ZnO 5%Bi LSV AM1.5.bin', 'zno 5%bi lsv am1.5.csv', 'ZnO 5%Bi LSV dark.bin', 'zno 5%bi lsv dark.csv', 'ZnO 5%Bi LSV UV.bin', 'zno 5%bi lsv uv.csv', 'ZnO 5%Bi LSV visible.bin', 'zno 5%bi lsv visible.csv', 'ZnO Au CA stability.bin', 'ZnO CA chop AM1.5.bin', 'zno ca chop am1.5.csv', 'ZnO CA chop UV.bin', 'zno ca chop uv.csv', 'ZnO CA chop visible.bin', 'zno ca chop visible.csv', 'ZnO CA stability AM1.5.bin', 'zno ca stability am1.5.csv', 'ZnO CA stability UV.bin', 'zno ca stability uv.csv', 'ZnO CA stability visible.bin', 'zno ca stability visible.csv', 'ZnO imp AM1.5.bin', 'zno imp am1.5.csv', 'ZnO imp dark.bin', 'zno imp dark.csv', 'ZnO imp UV.bin', 'zno imp uv.csv', 'ZnO imp visible.bin', 'zno imp visible.csv', 'ZnO LSV AM1.5.bin', 'zno lsv am1.5.csv', 'ZnO LSV dark.bin', 'zno lsv dark.csv', 'ZnO LSV UV.bin', 'zno lsv uv.csv', 'ZnO LSV visible.bin', 'zno lsv visible.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-06-16
# directory_name []
# file_name ['ZnO 3%Bi Au CA chop AM1.5.bin', 'zno 3%bi au ca chop am1.5.csv', 'ZnO 3%Bi Au CA chop UV.bin', 'zno 3%bi au ca chop uv.csv', 'ZnO 3%Bi Au CA chop visible.bin', 'ZnO 3%Bi Au CA Stability AM1.5.bin', 'ZnO 3%Bi Au CA Stability UV.bin', 'ZnO 3%Bi Au CA Stability visible.bin', 'ZnO 3%Bi Au imp AM1.5.bin', 'zno 3%bi au imp am1.5.csv', 'ZnO 3%Bi Au LSV AM1.5.bin', 'zno 3%bi au lsv am1.5.csv', 'ZnO Au CA chop AM1.5.bin', 'zno au ca chop am1.5.csv', 'ZnO Au CA chop UV.bin', 'zno au ca chop uv.csv', 'ZnO Au CA chop visible.bin', 'ZnO Au CA Stability AM1.5.bin', 'zno au ca stability am1.5.csv', 'ZnO Au CA Stability UV.bin', 'zno au ca stability uv.csv', 'ZnO Au CA Stability visible -1.bin', 'ZnO Au CA Stability visible.bin', 'zno au ca stability visible.csv', 'ZnO Au imp AM1.5.bin', 'zno au imp am1.5.csv', 'ZnO Au LSV AM1.5.bin', 'zno au lsv am1.5.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-06-20
# directory_name []
# file_name ['ZnO  2%Bi CA chop AM1.5.bin', 'zno  2%bi ca chop am1.5.csv', 'ZnO  2%Bi CA chop UV.bin', 'zno  2%bi ca chop uv.csv', 'ZnO  2%Bi CA chop visible.bin', 'zno  2%bi ca chop visible.csv', 'ZnO  2%Bi CA stability AM1.5.bin', 'zno  2%bi ca stability am1.5.csv', 'ZnO  2%Bi CA stability UV.bin', 'zno  2%bi ca stability uv.csv', 'ZnO  2%Bi CA stability visible.bin', 'zno  2%bi ca stability visible.csv', 'ZnO  4%Bi CA chop AM1.5.bin', 'ZnO  4%Bi CA chop AM1.5.csv', 'ZnO  4%Bi CA chop UV.bin', 'zno  4%bi ca chop uv.csv', 'ZnO  4%Bi CA chop visible.bin', 'zno  4%bi ca chop visible.csv', 'ZnO  4%Bi CA stability AM1.5.bin', 'zno  4%bi ca stability am1.5.csv', 'ZnO  4%Bi CA stability UV.bin', 'zno  4%bi ca stability uv.csv', 'ZnO  4%Bi CA stability visible.bin', 'ZnO  4%Bi CA stability visible.csv', 'ZnO 2%Bi imp AM1.5.bin', 'zno 2%bi imp am1.5.csv', 'ZnO 2%Bi imp dark.bin', 'zno 2%bi imp dark.csv', 'ZnO 2%Bi imp UV.bin', 'zno 2%bi imp uv.csv', 'ZnO 2%Bi imp visible.bin', 'zno 2%bi imp visible.csv', 'ZnO 2%Bi LSV AM1.5.bin', 'zno 2%bi lsv am1.5.csv', 'ZnO 2%Bi LSV dark.bin', 'zno 2%bi lsv dark.csv', 'ZnO 2%Bi LSV UV.bin', 'zno 2%bi lsv uv.csv', 'ZnO 2%Bi LSV visible.bin', 'zno 2%bi lsv visible.csv', 'ZnO 4%Bi imp AM1.5.bin', 'ZnO 4%Bi imp AM1.5.csv', 'ZnO 4%Bi imp dark.bin', 'ZnO 4%Bi imp dark.csv', 'ZnO 4%Bi imp UV.bin', 'zno 4%bi imp uv.csv', 'ZnO 4%Bi imp visible.bin', 'zno 4%bi imp visible.csv', 'ZnO 4%Bi LSV AM1.5.bin', 'ZnO 4%Bi LSV AM1.5.csv', 'ZnO 4%Bi LSV dark.bin', 'zno 4%bi lsv dark.csv', 'ZnO 4%Bi LSV UV.bin', 'zno 4%bi lsv uv.csv', 'ZnO 4%Bi LSV visible.bin', 'zno 4%bi lsv visible.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-06-24
# directory_name []
# file_name ['ZnO 1%Bi CA chop visible.bin', 'zno 1%bi ca chop visible.csv', 'ZnO 1%Bi imp dark.bin', 'zno 1%bi imp dark.csv', 'ZnO 1%Bi imp visible.bin', 'ZnO 1%Bi imp visible.csv', 'ZnO 1%Bi LSV dark.bin', 'zno 1%bi lsv dark.csv', 'ZnO 1%Bi LSV visible.bin', 'zno 1%bi lsv visible.csv', 'ZnO 2%Bi CA chop visible.bin', 'zno 2%bi ca chop visible.csv', 'ZnO 2%Bi imp dark.bin', 'zno 2%bi imp dark.csv', 'ZnO 2%Bi imp visible.bin', 'zno 2%bi imp visible.csv', 'ZnO 2%Bi LSV dark.bin', 'zno 2%bi lsv dark.csv', 'ZnO 2%Bi LSV visible.bin', 'zno 2%bi lsv visible.csv', 'ZnO 3%Bi CA chop visible.bin', 'zno 3%bi ca chop visible.csv', 'ZnO 3%Bi imp dark.bin', 'zno 3%bi imp dark.csv', 'ZnO 3%Bi imp visible.bin', 'zno 3%bi imp visible.csv', 'ZnO 3%Bi LSV dark.bin', 'zno 3%bi lsv dark.csv', 'ZnO 3%Bi LSV visible.bin', 'zno 3%bi lsv visible.csv', 'ZnO 4%Bi CA chop visible.bin', 'zno 4%bi ca chop visible.csv', 'ZnO 4%Bi imp dark.bin', 'zno 4%bi imp dark.csv', 'ZnO 4%Bi imp visible.bin', 'zno 4%bi imp visible.csv', 'ZnO 4%Bi LSV dark.bin', 'ZnO 4%Bi LSV dark.csv', 'ZnO 4%Bi LSV visible.bin', 'zno 4%bi lsv visible.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-06-26 CA 1hr and 30days later
# directory_name []
# file_name ['ZnO 1%Bi CA chop visible.bin', 'zno 1%bi ca chop visible.csv', 'ZnO 1%BI CA stability AM1.5.bin', 'zno 1%bi ca stability am1.5.csv', 'ZnO 1%BI CA stability UV.bin', 'zno 1%bi ca stability uv.csv', 'ZnO 1%BI CA stability visible.bin', 'zno 1%bi ca stability visible.csv', 'ZnO 3%Bi CA chop visible.bin', 'zno 3%bi ca chop visible.csv', 'ZnO 3%Bi CA stability AM1.5.bin', 'zno 3%bi ca stability am1.5.csv', 'ZnO 3%Bi CA stability UV.bin', 'zno 3%bi ca stability uv.csv', 'ZnO 3%Bi CA stability visible.bin', 'zno 3%bi ca stability visible.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-06-27
# directory_name []
# file_name ['ZnO 2%BI CA stability AM1.5.bin', 'zno 2%bi ca stability am1.5.csv', 'ZnO 2%BI CA stability UV.bin', 'zno 2%bi ca stability uv.csv', 'ZnO 2%BI CA stability visible.bin', 'zno 2%bi ca stability visible.csv', 'ZnO 4%BI CA stability AM1.5.bin', 'zno 4%bi ca stability am1.5.csv', 'ZnO 4%BI CA stability UV.bin', 'zno 4%bi ca stability uv.csv', 'ZnO 4%BI CA stability visible.bin', 'zno 4%bi ca stability visible.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-06-28
# directory_name []
# file_name ['ZnO 5%Bi CA stability AM1.5.bin', 'zno 5%bi ca stability am1.5.csv', 'ZnO 5%Bi CA stability UV.bin', 'zno 5%bi ca stability uv.csv', 'ZnO 5%Bi CA stability visible.bin', 'zno 5%bi ca stability visible.csv', 'ZnO CA stability AM1.5.bin', 'zno ca stability am1.5.csv', 'ZnO CA stability UV.bin', 'zno ca stability uv.csv', 'ZnO CA stability visible.bin', 'zno ca stability visible.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-07-12
# directory_name []
# file_name ['ZnO 2%Bi CA AM1.5.bin', 'zno 2%bi ca am1.5.csv', 'ZnO 2%Bi CA visible 2.bin', 'zno 2%bi ca visible 2.csv', 'ZnO 2%Bi CA visible.bin', 'zno 2%bi ca visible.csv', 'ZnO 2%Bi Imp dark.bin', 'zno 2%bi imp dark.csv', 'ZnO 2%Bi LSV AM1.5.bin', 'zno 2%bi lsv am1.5.csv', 'ZnO 2%Bi LSV dark.bin', 'zno 2%bi lsv dark.csv', 'ZnO 3%Bi CA AM1.5.bin', 'zno 3%bi ca am1.5.csv', 'ZnO 3%Bi CA stability AM 1.5 1hr.bin', 'zno 3%bi ca stability am 1.5 1hr.csv', 'ZnO 3%Bi CA stability AM1.5.bin', 'zno 3%bi ca stability am1.5.csv', 'ZnO 3%Bi CA stability visible 1hr.bin', 'zno 3%bi ca stability visible 1hr.csv', 'ZnO 3%Bi CA stability visible.bin', 'zno 3%bi ca stability visible.csv', 'ZnO 3%Bi CA visible.bin', 'ZnO 3%Bi CA visible.csv', 'ZnO 3%Bi Imp AM1.5.bin', 'zno 3%bi imp am1.5.csv', 'ZnO 3%Bi Imp dark.bin', 'zno 3%bi imp dark.csv', 'ZnO 3%Bi Imp visible.bin', 'zno 3%bi imp visible.csv', 'ZnO 3%Bi LSV dark.bin', 'zno 3%bi lsv dark.csv', 'zno 3%bi lsv visible.bin', 'zno 3%bi lsv visible.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-08-23
# directory_name []
# file_name ['colloidal seed ZnO CA AM1.5.bin', 'colloidal seed zno ca am1.5.csv', 'colloidal seed ZnO CA visible 1e-5.bin', 'colloidal seed zno ca visible 1e-5.csv', 'colloidal seed ZnO CA visible.bin', 'colloidal seed zno ca visible.csv', 'colloidal seed ZnO imp AM1.5.bin', 'colloidal seed zno imp am1.5.csv', 'colloidal seed ZnO imp dark.bin', 'colloidal seed zno imp dark.csv', 'colloidal seed ZnO LSV AM1.5.bin', 'colloidal seed zno lsv am1.5.csv', 'colloidal seed ZnO LSV dark.bin', 'colloidal seed zno lsv dark.csv', 'eth seed ZnO AM1.5.bin', 'eth seed zno am1.5.csv', 'eth seed ZnO imp AM1.5 2.bin', 'eth seed zno imp am1.5 2.csv', 'eth seed ZnO imp AM1.5 2smooth.bin', 'eth seed zno imp am1.5 2smooth.csv', 'eth seed ZnO imp AM1.5.bin', 'eth seed zno imp am1.5.csv', 'eth seed ZnO imp dark.bin', 'eth seed zno imp dark.csv', 'eth seed ZnO LSV AM1.5  1.bin', 'eth seed zno lsv am1.5  1.csv', 'eth seed ZnO LSV AM1.5  2.bin', 'eth seed zno lsv am1.5  2.csv', 'eth seed ZnO LSV AM1.5  EOC.bin', 'eth seed zno lsv am1.5  eoc.csv', 'eth seed ZnO LSV dark.bin', 'eth seed zno lsv dark.csv', 'eth seed ZnO visible 1.bin', 'eth seed zno visible 1.csv', 'eth seed ZnO visible 2.bin', 'eth seed zno visible 2.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-08-27
# directory_name []
# file_name ['colloidal seed ZnO CA AM1.5 0.01V.bin', 'colloidal seed zno ca am1.5 0.01v.csv', 'colloidal seed ZnO CA AM1.5 2.bin', 'colloidal seed zno ca am1.5 2.csv', 'colloidal seed ZnO CA AM1.5.bin', 'colloidal seed zno ca am1.5.csv', 'colloidal seed ZnO CA visible.bin', 'colloidal seed zno ca visible.csv', 'colloidal seed zno imp  am1.5.csv', 'colloidal seed ZnO imp AM1.5.bin', 'colloidal seed zno imp am1.5.csv', 'colloidal seed ZnO imp dark.bin', 'colloidal seed zno imp dark.csv', 'colloidal seed zno lsv  am1.5.csv', 'colloidal seed ZnO LSV AM1.5.bin', 'colloidal seed zno lsv am1.5.csv', 'colloidal seed ZnO LSV dark.bin', 'colloidal seed zno lsv dark.csv', 'sol gel seed ZnO CA AM1.5.bin', 'sol gel seed zno ca am1.5.csv', 'sol gel seed ZnO CA visible.bin', 'sol gel seed zno ca visible.csv', 'sol gel seed ZnO imp AM1.5 flat.bin', 'sol gel seed zno imp am1.5 flat.csv', 'sol gel seed ZnO imp dark.bin', 'sol gel seed ZnO LSV AM1.5 smooth.bin', 'sol gel seed zno lsv am1.5 smooth.csv', 'sol gel seed ZnO LSV AM1.5.bin', 'sol gel seed zno lsv am1.5.csv', 'sol gel seed ZnO LSV dark.bin', 'sol gel seed zno lsv dark.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-09-08
# directory_name []
# file_name ['ZnO CA AM1.5 0.01V.bin', 'ZnO CA AM1.5 10mins.bin', 'zno ca am1.5 10mins.csv', 'ZnO CA AM1.5 20mins.bin', 'zno ca am1.5 20mins.csv', 'ZnO CA AM1.5 5mins.bin', 'zno ca am1.5 5mins.csv', 'ZnO CA visible 10mins.bin', 'zno ca visible 10mins.csv', 'ZnO CA visible 20mins.bin', 'zno ca visible 20mins.csv', 'ZnO CA visible 5mins.bin', 'zno ca visible 5mins.csv', 'ZnO imp AM1.5 10mins.bin', 'zno imp am1.5 10mins.csv', 'ZnO imp AM1.5 20mins.bin', 'zno imp am1.5 20mins.csv', 'ZnO imp AM1.5 5mins.bin', 'zno imp am1.5 5mins.csv', 'ZnO LSV AM1.5 10mins.bin', 'zno lsv am1.5 10mins.csv', 'ZnO LSV AM1.5 20mins.bin', 'zno lsv am1.5 20mins.csv', 'ZnO LSV AM1.5 5mins.bin', 'zno lsv am1.5 5mins.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-10-26
# directory_name []
# file_name ['ZnO CA AM1.5 0.01V.bin', 'zno ca am1.5 0.01v.csv', 'ZnO CA AM1.5 0.5V 1.bin', 'zno ca am1.5 0.5v 1.csv', 'ZnO CA AM1.5 0.5V.bin', 'zno ca am1.5 0.5v.csv', 'ZnO CA UV 0.01V.bin', 'zno ca uv 0.01v.csv', 'ZnO CA UV 0.5V.bin', 'zno ca uv 0.5v.csv', 'ZnO CA visible 0.01V.bin', 'zno ca visible 0.01v.csv', 'ZnO CA visible 0.5V 1.bin', 'zno ca visible 0.5v 1.csv', 'ZnO CA visible 0.5V.bin', 'zno ca visible 0.5v.csv', 'ZnO Imp AM 1.5 SIMULATE.bin', 'zno imp am 1.5 simulate.csv', 'ZnO Imp AM 1.5.bin', 'zno imp am 1.5.csv', 'ZnO LSV AM 1.5.bin', 'ZnO LSV AM 1.5.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-11-02
# directory_name []
# file_name ['2%Bi ZnO CA AM1.5 +0.01V.bin', '2%bi zno ca am1.5 +0.01v.csv', '2%Bi ZnO CA AM1.5 +0.4V.bin', '2%bi zno ca am1.5 +0.4v.csv', '2%Bi ZnO CA UV +0.01V.bin', '2%bi zno ca uv +0.01v.csv', '2%Bi ZnO CA UV +0.4V.bin', '2%bi zno ca uv +0.4v.csv', '2%Bi ZnO CA visible +0.01V.bin', '2%bi zno ca visible +0.01v.csv', '2%Bi ZnO CA visible +0.4V.bin', '2%bi zno ca visible +0.4v.csv', '2%Bi ZnO Imp AM1.5 smooth SIMULATION.bin', '2%bi zno imp am1.5 smooth simulation.csv', '2%Bi ZnO Imp AM1.5 smooth.bin', '2%bi zno imp am1.5 smooth.csv', '2%Bi ZnO Imp AM1.5.bin', '2%bi zno imp am1.5.csv', '2%Bi ZnO LSV AM1.5.bin', '2%bi zno lsv am1.5.csv', '5%Bi ZnO CA AM1.5 +0.01V.bin', '5%bi zno ca am1.5 +0.01v.csv', '5%Bi ZnO CA AM1.5 +0.4V.bin', '5%bi zno ca am1.5 +0.4v.csv', '5%Bi ZnO CA UV +0.01V.bin', '5%bi zno ca uv +0.01v.csv', '5%Bi ZnO CA UV +0.4V.bin', '5%bi zno ca uv +0.4v.csv', '5%Bi ZnO CA visible +0.01V.bin', '5%bi zno ca visible +0.01v.csv', '5%Bi ZnO CA visible +0.4V.bin', '5%bi zno ca visible +0.4v.csv', '5%Bi ZnO Imp AM1.5 SIMULATE.bin', '5%bi zno imp am1.5 simulate.csv', '5%Bi ZnO Imp AM1.5.bin', '5%bi zno imp am1.5.csv', '5%Bi ZnO LSV AM1.5.bin', '5%bi zno lsv am1.5.csv', 'ZnO CA AM 1.5 +0.4V.bin', 'zno ca am 1.5 +0.4v.csv', 'ZnO CA AM 1.5 -0.4V.bin', 'zno ca am 1.5 -0.4v.csv', 'ZnO CA UV +0.4V.bin', 'zno ca uv +0.4v.csv', 'ZnO CA UV -0.4V.bin', 'zno ca uv -0.4v.csv', 'ZnO CA visible +0.4V.bin', 'zno ca visible +0.4v.csv', 'ZnO CA visible -0.4V.bin', 'zno ca visible -0.4v.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-11-04
# directory_name []
# file_name ['3%Bi ZnO CA Am1.5 +0.01V.bin', '3%bi zno ca am1.5 +0.01v.csv', '3%Bi ZnO CA AM1.5 +0.4V.bin', '3%bi zno ca am1.5 +0.4v.csv', '3%Bi ZnO CA UV +0.01V.bin', '3%bi zno ca uv +0.01v.csv', '3%Bi ZnO CA UV +0.4V.bin', '3%bi zno ca uv +0.4v.csv', '3%Bi ZnO CA visible +0.01V.bin', '3%bi zno ca visible +0.01v.csv', '3%Bi ZnO CA visible +0.4V.bin', '3%bi zno ca visible +0.4v.csv', '3%Bi ZnO Imp AM1.5 SIMULATE.bin', '3%bi zno imp am1.5 simulate.csv', '3%Bi ZnO Imp AM1.5.bin', '3%bi zno imp am1.5.csv', '3%Bi ZnO LSV AM1.5.bin', '3%bi zno lsv am1.5.csv', '4%Bi ZnO CA Am1.5 +0.01V.bin', '4%bi zno ca am1.5 +0.01v.csv', '4%Bi ZnO CA AM1.5 +0.4V.bin', '4%bi zno ca am1.5 +0.4v.csv', '4%Bi ZnO CA UV +0.01V.bin', '4%bi zno ca uv +0.01v.csv', '4%Bi ZnO CA UV +0.4V.bin', '4%bi zno ca uv +0.4v.csv', '4%Bi ZnO CA visible +0.01V.bin', '4%bi zno ca visible +0.01v.csv', '4%Bi ZnO CA visible +0.4V.bin', '4%bi zno ca visible +0.4v.csv', '4%Bi ZnO Imp AM1.5 SIMULATE.bin', '4%bi zno imp am1.5 simulate.csv', '4%Bi ZnO Imp AM1.5.bin', '4%bi zno imp am1.5.csv', '4%Bi ZnO LSV AM1.5.bin', '4%bi zno lsv am1.5.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-11-16
# directory_name []
# file_name ['2%Bi ZnO CA AM1.5 +0.4V 45mins.bin', '2%bi zno ca am1.5 +0.4v 45mins.csv', '2%Bi ZnO CA UV +0.4V 45mins.bin', '2%bi zno ca uv +0.4v 45mins.csv', '2%Bi ZnO CA visible +0.4V 45mins.bin', '2%bi zno ca visible +0.4v 45mins.csv', '2%Bi ZnO Imp AM1.5 45mins SIMULATE.bin', '2%bi zno imp am1.5 45mins simulate.csv', '2%Bi ZnO Imp AM1.5 45mins.bin', '2%bi zno imp am1.5 45mins.csv', '2%Bi ZnO LSV AM1.5 45mins.bin', '2%bi zno lsv am1.5 45mins.csv', 'ZnO CA AM1.5 +0.4V 45mins.bin', 'zno ca am1.5 +0.4v 45mins.csv', 'ZnO CA UV +0.4V 45mins.bin', 'zno ca uv +0.4v 45mins.csv', 'ZnO CA visible +0.4V 45mins.bin', 'zno ca visible +0.4v 45mins.csv', 'ZnO Imp AM1.5 45mins SIMULATE.bin', 'zno imp am1.5 45mins simulate.csv', 'ZnO Imp AM1.5 45mins.bin', 'zno imp am1.5 45mins.csv', 'ZnO LSV AM1.5 45mins.bin', 'zno lsv am1.5 45mins.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-11-27
# directory_name []
# file_name ['2%Bi ZnO photostability 2hrs.bin', '2%bi zno photostability 2hrs.csv', '2%Bi ZnO photostability 45mins.bin', '2%bi zno photostability 45mins.csv', 'ZnO photostability 2 2hrs.bin', 'zno photostability 2 2hrs.csv', 'ZnO photostability 2 45mins.bin', 'zno photostability 2 45mins.csv', 'ZnO photostability 45mins.bin', 'zno photostability 45mins.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2019-5-16
# directory_name []
# file_name ['ZnO 2h CA Chop Am 1.5.bin', 'ZnO 2h CA Chop UV.bin', 'ZnO 2h CA Stability Am 1.5.bin', 'ZnO 2h CA Stability Am 1.5.csv', 'ZnO 2h CA Stability UV.bin', 'ZnO 2h EIS Am 1.5.bin', 'ZnO 2h EIS UV.bin', 'ZnO 2h LSV Am 1.5.bin', 'ZnO 2h LSV UV.bin', 'ZnO Au old CA Chop AM 1.5.bin', 'ZnO Au old CA Chop AM 1.5.bin.csv', 'ZnO Au old CA stability AM 1.5.bin', 'ZnO Au old CA stability AM 1.5.csv', 'ZnO Au old CA stability UV.bin', 'ZnO Au old CA stability UV.csv', 'ZnO Au old LSV AM 1.5.bin', 'ZnO Au old LSV AM 1.5.csv', 'ZnO Bi old CA chop UV.csv', 'ZnO Bi old CA stability UV.bin', 'ZnO Bi old CA stability UV.csv', 'ZnO Bi old EIS UV.bin', 'ZnO Bi old EIS UV.csv', 'ZnO Bi old LSV UV.bin', 'ZnO Bi old LSV UV.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2020-01-19
# directory_name []
# file_name ['1%Bi ZnO CA AM1.5 +0.4V 2 h.bin', '1%bi zno ca am1.5 +0.4v 2 h.csv', '1%Bi ZnO CA AM1.5 +0.4V 45mins.bin', '1%bi zno ca am1.5 +0.4v 45mins.csv', '1%Bi ZnO CA UV +0.4V 2 h.bin', '1%bi zno ca uv +0.4v 2 h.csv', '1%Bi ZnO CA UV +0.4V 45mins.bin', '1%bi zno ca uv +0.4v 45mins.csv', '1%Bi ZnO CA visible +0.4V 2 h.bin', '1%bi zno ca visible +0.4v 2 h.csv', '1%Bi ZnO CA visible +0.4V 45mins.bin', '1%bi zno ca visible +0.4v 45mins.csv', '1%Bi ZnO Imp AM1.5 2 h SIMULATE.bin', '1%bi zno imp am1.5 2 h simulate.csv', '1%Bi ZnO Imp AM1.5 2 h.bin', '1%bi zno imp am1.5 2 h.csv', '1%Bi ZnO Imp AM1.5 45mins SIMULATE.bin', '1%bi zno imp am1.5 45mins simulate.csv', '1%Bi ZnO Imp AM1.5 45mins.bin', '1%bi zno imp am1.5 45mins.csv', '1%Bi ZnO LSV AM1.5 2 h.bin', '1%bi zno lsv am1.5 2 h.csv', '1%Bi ZnO LSV AM1.5 45mins.bin', '1%bi zno lsv am1.5 45mins.csv', '1%Bi ZnO photostability 2 h.bin', '1%bi zno photostability 2 h.csv', '1%Bi ZnO photostability 45mins.bin', '1%bi zno photostability 45mins.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2020-01-26
# directory_name []
# file_name ['1%Bi ZnO CA AM1.5 +0.4V 2 h.bin', '1%bi zno ca am1.5 +0.4v 2 h.csv', '1%Bi ZnO CA UV +0.4V 2 h.bin', '1%bi zno ca uv +0.4v 2 h.csv', '1%Bi ZnO CA visible +0.4V 2 h.bin', '1%bi zno ca visible +0.4v 2 h.csv', '1%Bi ZnO Imp AM1.5 2 h.bin', '1%bi zno imp am1.5 2 h.csv', '1%Bi ZnO LSV AM1.5 2 h.bin', '1%bi zno lsv am1.5 2 h.csv', '1%Bi ZnO photostability 2 h.bin', '1%bi zno photostability 2 h.csv', 'etch ZnO CA AM1.5 +0.4V 2 h.bin', 'etch zno ca am1.5 +0.4v 2 h.csv', 'etch ZnO CA UV +0.4V 2 h.bin', 'etch zno ca uv +0.4v 2 h.csv', 'etch ZnO CA visible +0.4V 2 h.bin', 'etch zno ca visible +0.4v 2 h.csv', 'etch ZnO Imp AM1.5 2 h.bin', 'etch zno imp am1.5 2 h.csv', 'etch ZnO LSV AM1.5 +0.4V 2 h.bin', 'etch zno lsv am1.5 +0.4v 2 h.csv', 'etch ZnO photostability 2 h.bin', 'etch zno photostability 2 h.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2020-02-19
# directory_name []
# file_name ['1.5%Bi ZnO CA AM1.5 +0.4V 2 h.bin', '1.5%bi zno ca am1.5 +0.4v 2 h.csv', '1.5%Bi ZnO CA UV +0.4V 2 h.bin', '1.5%bi zno ca uv +0.4v 2 h.csv', '1.5%Bi ZnO CA visible +0.4V 2 h.bin', '1.5%bi zno ca visible +0.4v 2 h.csv', '1.5%Bi ZnO Imp AM1.5 2 h SIMULATE.bin', '1.5%bi zno imp am1.5 2 h simulate.csv', '1.5%Bi ZnO Imp AM1.5 2 h.bin', '1.5%bi zno imp am1.5 2 h.csv', '1.5%Bi ZnO LSV AM1.5 2 h.bin', '1.5%bi zno lsv am1.5 2 h.csv', '1.5%Bi ZnO photostability 2 h.bin', '1.5%bi zno photostability 2 h.csv', '2.5%Bi  ZnO LSV AM1.5 2 h.bin', '2.5%bi  zno lsv am1.5 2 h.csv', '2.5%Bi ZnO CA AM1.5 2 h.bin', '2.5%bi zno ca am1.5 2 h.csv', '2.5%Bi ZnO CA UV +0.4V 2 h.bin', '2.5%bi zno ca uv +0.4v 2 h.csv', '2.5%Bi ZnO CA visible +0.4V 2 h.bin', '2.5%bi zno ca visible +0.4v 2 h.csv', '2.5%Bi ZnO Imp AM1.5 2 h SIMULATE.bin', '2.5%bi zno imp am1.5 2 h simulate.csv', '2.5%Bi ZnO Imp AM1.5 2 h.bin', '2.5%bi zno imp am1.5 2 h.csv', '2.5%Bi ZnO photostability 2 h.bin', '2.5%bi zno photostability 2 h.csv', 'IMG_20200220_181406.jpg', 'IMG_20200220_181526.jpg']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\2020-03-07
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\Research project\koko EIS\April samples
# directory_name []
# file_name ['CA bismuth 1e-8.bin', 'CA bismuth 1e-8.csv', 'CA for bismuth.bin', 'ca for bismuth.csv', 'CA pure ZnO.bin', 'CA pure ZnO.csv', 'CA ZnO Au 20s.bin', 'CA ZnO Au 20s.csv', 'EIS bismuth.bin', 'EIS bismuth.csv', 'EIS pure ZnO.bin', 'EIS pure ZnO.csv', 'EIS ZnO Au 20s.bin', 'LSV bismuth 3V.bin', 'LSV bismuth 3V.csv', 'LSV bismuth.csv', 'LSV pure ZnO.bin', 'LSV pure ZnO.csv', 'LSV ZnO Au 20s 5V.csv.bin', 'LSV ZnO Au 20s 8V.csv', 'LSV ZnO Au 20s.bin', 'LSV ZnO Au 20s.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\hakim UV-vis
# directory_name ['Hakeem  01-11-19', 'Hakeem 03-11-19', 'Hakeem 14-02-19', 'Hakeem 15-11-19 UV-vis']
# file_name ['blank.DSW', 'Complete data.csv', 'Complete data.DSW', 'Complete data.RSW', 'test.DSW', 'UV-vis 1st solgel.BSW']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\hakim UV-vis\Hakeem  01-11-19
# directory_name []
# file_name ['01-11-19.csv', '01-11-19.DSW', 'new data.csv']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\hakim UV-vis\Hakeem 03-11-19
# directory_name []
# file_name ['03-11-19.BSW', '03-11-19.csv', 'blank.DSW']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\hakim UV-vis\Hakeem 14-02-19
# directory_name []
# file_name ['First UV-vis result.csv', 'test1.DSW']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\hakim UV-vis\Hakeem 15-11-19 UV-vis
# directory_name ['New Folder']
# file_name ['45mins rod growths.csv', '45mins rod growths.DSW', 'blank.DSW']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\hakim UV-vis\Hakeem 15-11-19 UV-vis\New Folder
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\Research project\koko EIS\PEC data
# directory_name ['April samples']
# file_name []
#
# directory_path \Users\User\Desktop\Research project\koko EIS\PEC data\April samples
# directory_name []
# file_name ['CA bismuth 1e-8.bin', 'CA bismuth 1e-8.csv', 'CA for bismuth.bin', 'ca for bismuth.csv', 'CA pure ZnO.bin', 'CA pure ZnO.csv', 'CA ZnO Au 20s.bin', 'CA ZnO Au 20s.csv', 'EIS bismuth.bin', 'EIS bismuth.csv', 'EIS pure ZnO.bin', 'EIS pure ZnO.csv', 'EIS ZnO Au 20s.bin', 'LSV bismuth 3V.bin', 'LSV bismuth 3V.csv', 'LSV bismuth.csv', 'LSV pure ZnO.bin', 'LSV pure ZnO.csv', 'LSV ZnO Au 20s 5V.csv.bin', 'LSV ZnO Au 20s 8V.csv', 'LSV ZnO Au 20s.bin', 'LSV ZnO Au 20s.csv', 'to_drchang excel.xlsx']
#
# directory_path \Users\User\Desktop\Research project\koko EIS\ZnO Bi~1per
# directory_name []
# file_name ['ZnO CA AM1.5.bin', 'ZnO CA AM1.5.csv', 'ZnO CA UVcut.bin', 'ZnO Imp AM1.5.bin', 'ZnO Imp AM1.5.csv', 'ZnO Imp Dark.bin', 'ZnO Imp Dark.csv', 'ZnO Imp UVcut.bin', 'ZnO Imp UVcut.csv', 'ZnO LSV AM1.5.bin', 'ZnO LSV Dark.bin', 'ZnO LSV Dark.csv', 'ZnO LSV UVcut.bin', 'ZnO-Bi~1per CA AM1.5.bin', 'ZnO-Bi~1per CA AM1.5.csv', 'ZnO-Bi~1per CA UV.bin', 'ZnO-Bi~1per CA UV.csv', 'ZnO-Bi~1per CA UVcut 2.bin', 'ZnO-Bi~1per CA UVcut 2.csv', 'ZnO-Bi~1per CA UVcut.bin', 'ZnO-Bi~1per CA UVcut.csv', 'ZnO-Bi~1per Imp AM1.5.bin', 'ZnO-Bi~1per Imp AM1.5.csv', 'ZnO-Bi~1per Imp Dark.bin', 'ZnO-Bi~1per Imp Dark.csv', 'ZnO-Bi~1per Imp UV.bin', 'ZnO-Bi~1per Imp UV.csv', 'ZnO-Bi~1per Imp UVcut.bin', 'ZnO-Bi~1per Imp UVcut.csv', 'ZnO-Bi~1per LSV AM1.5.bin', 'ZnO-Bi~1per LSV AM1.5.csv', 'ZnO-Bi~1per LSV Dark.bin', 'ZnO-Bi~1per LSV Dark.csv', 'ZnO-Bi~1per LSV UV.bin', 'ZnO-Bi~1per LSV UV.csv', 'ZnO-Bi~1per LSV UVcut.bin', 'ZnO-Bi~1per LSV UVcut.csv', 'ZnO-Bi~1per Sta AM1.5.bin', 'ZnO-Bi~1per Sta AM1.5.csv', 'ZnO-Bi~1per Sta UV.bin', 'ZnO-Bi~1per Sta UV.csv', 'ZnO-Bi~1per Sta UVcut.bin', 'ZnO-Bi~1per Sta UVcut.csv', 'ZnO-Bi~3per CA AM1.5.bin', 'ZnO-Bi~3per CA AM1.5.csv', 'ZnO-Bi~3per CA UV.bin', 'ZnO-Bi~3per CA UV.csv', 'ZnO-Bi~3per CA UVcut.bin', 'ZnO-Bi~3per CA UVcut.csv', 'ZnO-Bi~3per Imp AM1.5.bin', 'ZnO-Bi~3per Imp AM1.5.csv', 'ZnO-Bi~3per Imp Dark.bin', 'ZnO-Bi~3per Imp Dark.csv', 'ZnO-Bi~3per Imp UV.bin', 'ZnO-Bi~3per Imp UV.csv', 'ZnO-Bi~3per Imp UVcut.bin', 'ZnO-Bi~3per Imp UVcut.csv', 'ZnO-Bi~3per LSV AM1.5.bin', 'ZnO-Bi~3per LSV AM1.5.csv', 'ZnO-Bi~3per LSV Dark.bin', 'ZnO-Bi~3per LSV Dark.csv', 'ZnO-Bi~3per LSV UV.bin', 'ZnO-Bi~3per LSV UV.csv', 'ZnO-Bi~3per LSV UVcut.bin', 'ZnO-Bi~3per LSV UVcut.csv', 'ZnO-Bi~3per Sta AM1.5.bin', 'ZnO-Bi~3per Sta AM1.5.csv', 'ZnO-Bi~3per Sta UV.bin', 'ZnO-Bi~3per Sta UV.csv', 'ZnO-Bi~3per Sta UVcut.bin', 'ZnO-Bi~3per Sta UVcut.csv', 'ZnO-Bi~L CA AM1.5.bin', 'ZnO-Bi~L CA AM1.5.csv', 'ZnO-Bi~L CA UVcut.bin', 'ZnO-Bi~L CA UVcut.csv', 'ZnO-Bi~L Imp AM1.5.bin', 'ZnO-Bi~L Imp AM1.5.csv', 'ZnO-Bi~L Imp UVcut.bin', 'ZnO-Bi~L Imp UVcut.csv', 'ZnO-Bi~L LSV UVcut.bin', 'ZnO-Bi~L LSV UVcut.csv']
#
# directory_path \Users\User\Desktop\Research project\New folder
# directory_name ['Autosave', 'GroupShared', 'OCTemp']
# file_name ['Backup.opj', 'excel.otw', 'Filter.ini', 'MenuCommands_E.txt', 'MRFiles.ini', 'NLSF.ini', 'NLSFOide.ini', 'NLSFwizard.ini', 'NLSFwiz_OPS.bmp', 'Olbtedit.ini', 'OLicense.lic', 'OrgApp.ini', 'origin.ini', 'Origin8.INI', 'OUbtn.ini', 'SYSTEM.CNF', 'Template.ini', 'Userdef.bmp']
#
# directory_path \Users\User\Desktop\Research project\New folder\Autosave
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\Research project\New folder\GroupShared
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\Research project\New folder\OCTemp
# directory_name ['ORIGINC']
# file_name ['dbEdit.OCB', 'impASC.OCB', 'impExcel.OCB', 'layadd.OCB', 'wclear.OCB']
#
# directory_path \Users\User\Desktop\Research project\New folder\OCTemp\ORIGINC
# directory_name ['ORIGINLAB', 'SYSTEM']
# file_name []
#
# directory_path \Users\User\Desktop\Research project\New folder\OCTemp\ORIGINC\ORIGINLAB
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\Research project\New folder\OCTemp\ORIGINC\SYSTEM
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\Research project\PL 2hrs
# directory_name ['325PL', '514PL']
# file_name []
#
# directory_path \Users\User\Desktop\Research project\PL 2hrs\325PL
# directory_name []
# file_name ['Pure ZnO 325nm PL.txt', 'Pure ZnO 325nm PL_smoothing.txt', 'Sample 1% Bi 325nm PL.txt', 'Sample 1% Bi 325nm PL_smoothing.txt', 'sample 2% Bi.txt', 'sample 2% Bi_smoothing.txt', 'sample 3% Al.txt', 'sample 3% Al_smoothing.txt', 'sample 3% Bi.txt', 'sample 3% Bi_smoothing.txt', 'sample 4% Bi.txt', 'sample 4% Bi_smoothing.txt', 'sample 5% Al.txt', 'sample 5% Al_smoothing.txt']
#
# directory_path \Users\User\Desktop\Research project\PL 2hrs\514PL
# directory_name []
# file_name ['pure ZnO 514nm PL.txt', 'sample 1% Bi 514nm PL.txt', 'sample 1% Bi 514nm PL_smoothing.txt', 'sample 2% Bi 514nm PL.txt', 'sample 2% Bi 514nm PL_smoothing.txt', 'sample 3% Al 514nm PL.txt', 'sample 3% Al 514nm PL_smoothing.txt', 'sample 3% Bi 514nm PL.txt', 'sample 3% Bi 514nm PL_smoothing.txt', 'sample 4% Bi 514nm PL.txt', 'sample 4% Bi 514nm PL_smoothing.txt', 'sample 5% Al 514nm PL.txt', 'sample 5% Al 514nm PL_smoothing.txt']
#
# directory_path \Users\User\Desktop\Research project\Plotted data
# directory_name ['First set 45mins growth time', 'Second set start 26-10-19']
# file_name []
#
# directory_path \Users\User\Desktop\Research project\Plotted data\First set 45mins growth time
# directory_name []
# file_name ['2%Bi ZnO UV-vis.xlsx', '3%Bi ZnO UV-vis.xlsx', '4%Bi ZnO UV-vis.xlsx', '5%Bi ZnO UV-vis.xlsx', 'CA AM1.5 Cl.xlsx', 'CA AM1.5 seed layer.xlsx', 'CA for AM1.5G.xlsx', 'CA for UV light.xlsx', 'CA for Visible light.xlsx', 'CA stability for AM1.5  1hr.xlsx', 'CA stability for AM1.5.xlsx', 'CA stability for UV 1hr.xlsx', 'CA stability for UV.xlsx', 'CA stability for visible  1hr.xlsx', 'CA stability for visible.xlsx', 'CA visible Cl.xlsx', 'CA visible light 24-06.xlsx', 'CA visible seed layer.xlsx', 'Gold sputtered material.pptx', 'imp Cl.xlsx', 'imp seed layer.xlsx', 'Impedance data AM1.5.xlsx', 'Impedance data dark.xlsx', 'Impedance data UV.xlsx', 'Impedance data visible.xlsx', 'LSV AM1.5 Cl.xlsx', 'LSV AM1.5 seed layer.xlsx', 'LSV data AM1.5G.xlsx', 'LSV data Dark.xlsx', 'LSV data UV.xlsx', 'LSV data Visible.xlsx', 'todrchang.xlsx', 'UV vis data.xlsx', 'UV-vis.xlsx', 'ZnO 3%Bi LSV.xlsx']
#
# directory_path \Users\User\Desktop\Research project\Plotted data\Second set start 26-10-19
# directory_name ['Autosave', 'GroupShared', 'OCTemp', 'Themes']
# file_name ['Backup.opj', 'CA AM 1.5G ZnO vs applied voltage.xlsx', 'CA AM1.5 0.4V.opj', 'CA AM1.5 0.4V.xlsx', 'CA UV 0.4V.xlsx', 'CA UV ZnO vs applied voltage.xlsx', 'CA visible 0.4V.xlsx', 'CA visible ZnO vs applied voltage.xlsx', 'CustomColors.ini', 'excel.otw', 'Filter.ini', 'Impedance data.xlsx', 'LSV.xlsx', 'LTHistory.txt', 'MenuCommands_E.txt', 'MRFiles.ini', 'my results.opj', 'NLSF.ini', 'NLSFOide.ini', 'NLSFwizard.ini', 'NLSFwiz_OPS.bmp', 'Olbtedit.ini', 'OLicense.lic', 'OrgApp.ini', 'origin.ini', 'Origin8.INI', 'OUbtn.ini', 'PL 2hrs.xlsx', 'Result conitinues.opj', 'SYSTEM.CNF', 'Template.ini', 'Template.xml', 'UpDown_Buffer.txt', 'Userdef.bmp', 'UV-vis for 2hrs growth time.xlsx', 'XRD 2hrs data.xlsx']
#
# directory_path \Users\User\Desktop\Research project\Plotted data\Second set start 26-10-19\Autosave
# directory_name []
# file_name ['my results-826883.opj']
#
# directory_path \Users\User\Desktop\Research project\Plotted data\Second set start 26-10-19\GroupShared
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\Research project\Plotted data\Second set start 26-10-19\OCTemp
# directory_name ['ORIGINC']
# file_name ['blpwiz.OCB', 'blrect.OCB', 'blsubtract.OCB', 'layadd.OCB', 'legendupdate.OCB', 'normalize.OCB', 'pk setting.OCB', 'pkarea.OCB', 'pkmax.OCB', 'plotstack.OCB', 'smooth.OCB', 'startBP.OCB', 'vnormalize.OCB']
#
# directory_path \Users\User\Desktop\Research project\Plotted data\Second set start 26-10-19\OCTemp\ORIGINC
# directory_name ['ORIGINLAB', 'SYSTEM']
# file_name []
#
# directory_path \Users\User\Desktop\Research project\Plotted data\Second set start 26-10-19\OCTemp\ORIGINC\ORIGINLAB
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\Research project\Plotted data\Second set start 26-10-19\OCTemp\ORIGINC\SYSTEM
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\Research project\Plotted data\Second set start 26-10-19\Themes
# directory_name ['AnalysisAndReportTable']
# file_name []
#
# directory_path \Users\User\Desktop\Research project\Plotted data\Second set start 26-10-19\Themes\AnalysisAndReportTable
# directory_name []
# file_name ['0-blpwiz-Last used.oix', '0-normalize-Last used.ois', '0-plotstack-Last used.ois', '0-smooth-Last used.ois']
#
# directory_path \Users\User\Desktop\shola_demo
# directory_name ['mb_demo']
# file_name []
#
# directory_path \Users\User\Desktop\shola_demo\mb_demo
# directory_name []
# file_name []
#
# directory_path \Users\User\Desktop\Tableau materials
# directory_name ['Data II', 'Forecasting and Time Series Analysis in Tableau', 'Getting started with tableau desktop', 'Tableau real courses data']
# file_name ['Filter hierarchy.JPG']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II
# directory_name ['add_a_filter_to_context_starter', 'add_a_forecast_to_a_view_starter_10.0', 'add_location_data_starter_10.0', 'Apply_A_Filter_To_Multiple_Data_Sources_Starter_10.0_WNAddcv', 'blend_data_from_two_sources_starter_10.0', 'blend_data_using_custom_relationships_starter_10.0', 'build_a_map_with_custom_geocoding_starter_10.0', 'calculate_the_average_product_profit_by_category_starter_10.0_p4ntjei', 'create_advanced_filter_actions_starter_10.0', 'create_a_bar-in-bar_chart_starter_10.0', 'create_a_bullet_graph_starter_10.0', 'create_a_data_extract_starter_10.0', 'create_trend_lines_with_small_multiples_starter_10.0', 'Desktop_I_Review_Workbook_starter_10.0', 'filter_percent_of_sales_starter_10.0', "improve_a_dashboard's_design_starter_10.0", 'join_tables_and_build_a_view_starter_10.0', 'plot_data_on_an_image_starter_10.0', 'profitability_as_percent_of_total_starter_10.0', 'union_data_and_merge_fields_starter_v10.0', 'use_an_aggregated_dimension_in_a_calculation_starter_10.0', 'use_a_box_plot_to_view_distributions_starter_10.0', 'use_a_histogram_to_view_distributions_starter_10.0', 'use_a_nested_parameter_for_dynamic_selection_starter_10.0', 'use_a_parameter_in_a_filter_starter_10.0', 'use_combined_sets_starter_10.0', "what's_the_story_starter_10.0"]
# file_name ['add_a_forecast_to_a_view_starter_10.0.twbx', 'Body_Map.gif', 'create_advanced_filter_actions_starter_10.0.twbx', 'create_a_bar-in-bar_chart_starter_10.0.twbx', 'create_a_bullet_graph_starter_10.0.twbx', 'create_trend_lines_with_small_multiples_starter_10.0.twbx', "improve_a_dashboard's_design_starter_10.0.twbx", 'plot_data_on_an_image_starter_10.0.twbx', 'use_a_box_plot_to_view_distributions_starter_10.0.twbx', 'use_a_histogram_to_view_distributions_starter_10.0.twbx', "what's_the_story_starter_10.0.twbx"]
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter
# directory_name ['Data', 'TwbxExternalCache']
# file_name ['add_a_filter_to_context_starter.twb']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\Data
# directory_name ['Courses Workbooks']
# file_name []
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\Data\Courses Workbooks
# directory_name []
# file_name ['Global Superstore v8-2016.xlsx']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\TwbxExternalCache
# directory_name ['TwbxResultsCacheV3', 'TwbxTimestampsCacheV3']
# file_name []
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\TwbxExternalCache\TwbxResultsCacheV3
# directory_name ['2019333569', '2062059224', '599108839']
# file_name []
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\TwbxExternalCache\TwbxResultsCacheV3\2019333569
# directory_name []
# file_name ['.bin', '.key']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\TwbxExternalCache\TwbxResultsCacheV3\2062059224
# directory_name []
# file_name ['.bin', '.key']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\TwbxExternalCache\TwbxResultsCacheV3\599108839
# directory_name []
# file_name ['.bin', '.key']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\TwbxExternalCache\TwbxTimestampsCacheV3
# directory_name ['1902650861', '291079188', '3243002329']
# file_name []
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\TwbxExternalCache\TwbxTimestampsCacheV3\1902650861
# directory_name []
# file_name ['.bin', '.key']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\TwbxExternalCache\TwbxTimestampsCacheV3\291079188
# directory_name []
# file_name ['.bin', '.key']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_filter_to_context_starter\TwbxExternalCache\TwbxTimestampsCacheV3\3243002329
# directory_name []
# file_name ['.bin', '.key']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_forecast_to_a_view_starter_10.0
# directory_name ['Data', 'TwbxExternalCache']
# file_name ['add_a_forecast_to_a_view_starter.twb']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_forecast_to_a_view_starter_10.0\Data
# directory_name ['Data']
# file_name []
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_forecast_to_a_view_starter_10.0\Data\Data
# directory_name []
# file_name ['Global Superstore.xls']
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_forecast_to_a_view_starter_10.0\TwbxExternalCache
# directory_name ['TwbxResultsCacheV3', 'TwbxTimestampsCacheV3']
# file_name []
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_forecast_to_a_view_starter_10.0\TwbxExternalCache\TwbxResultsCacheV3
# directory_name ['1903885931']
# file_name []
#
# directory_path \Users\User\Desktop\Tableau materials\Data II\add_a_forecast_to_a_view_starter_10.0\TwbxExternalCache\TwbxResultsCacheV3\1903885931
# directory_name []
# file_name ['.bin', '.key']
#
# ...
#
# directory_path \Users\User\Desktop\Web scraping\Example code regex\__MACOSX\3156OS - Code files
# directory_name ['ch2', 'ch3', 'ch4', 'ch5']
# file_name ['._.DS_Store', '._ch2', '._ch3', '._ch4', '._ch5']
#
# directory_path \Users\User\Desktop\Web scraping\Example code regex\__MACOSX\3156OS - Code files\ch2
# directory_name []
# file_name ['._.DS_Store', '._eg1.py', '._eg10.py', '._eg11.py', '._eg12.py', '._eg13.py', '._eg14.py', '._eg15.py', '._eg16.py', '._eg17.py', '._eg18.py', '._eg19.py', '._eg2.py', '._eg20.py', '._eg21.py', '._eg22.py', '._eg23.py', '._eg24.py', '._eg25.py', '._eg26.py', '._eg27.py', '._eg28.py', '._eg29.py', '._eg3.py', '._eg30.py', '._eg31.py', '._eg32.py', '._eg33.py', '._eg34.py', '._eg35.py', '._eg36.py', '._eg37.py', '._eg38.py', '._eg39.py', '._eg4.py', '._eg40.py', '._eg41.py', '._eg42.py', '._eg43.py', '._eg44.py', '._eg45.py', '._eg46.py', '._eg47.py', '._eg48.py', '._eg49.py', '._eg5.py', '._eg50.py', '._eg51.py', '._eg52.py', '._eg53.py', '._eg54.py', '._eg55.py', '._eg56.py', '._eg6.py', '._eg7.py', '._eg8.py', '._eg9.py']
#
# directory_path \Users\User\Desktop\Web scraping\Example code regex\__MACOSX\3156OS - Code files\ch3
# directory_name []
# file_name ['._.DS_Store', '._eg1.py', '._eg10.py', '._eg11.py', '._eg12.py', '._eg13.py', '._eg14.py', '._eg15.py', '._eg16.py', '._eg17.py', '._eg2.py', '._eg3.py', '._eg4.py', '._eg5.py', '._eg6.py', '._eg7.py', '._eg8.py', '._eg9.py']
#
# directory_path \Users\User\Desktop\Web scraping\Example code regex\__MACOSX\3156OS - Code files\ch4
# directory_name []
# file_name ['._.DS_Store', '._eg1.py', '._eg10.py', '._eg11.py', '._eg12.py', '._eg13.py', '._eg14.py', '._eg2.py', '._eg3.py', '._eg4.py', '._eg5.py', '._eg6.py', '._eg7.py', '._eg8.py', '._eg9.py']
#
# directory_path \Users\User\Desktop\Web scraping\Example code regex\__MACOSX\3156OS - Code files\ch5
# directory_name []
# file_name ['._.DS_Store', '._eg1.py', '._eg10.py', '._eg11.py', '._eg12.py', '._eg13.py', '._eg14.py', '._eg15.py', '._eg2.py', '._eg3.py', '._eg4.py', '._eg5.py', '._eg6.py', '._eg7.py', '._eg8.py', '._eg9.py']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash
# directory_name ['1. Introduction - UPDATED -', '10. Writing data to Excel files', '11. Scrapy POST requests', '12. The Media Pipeline', '13. Paid and Free proxies with ScrapySplash', '14. BONUS', '2. XPath Selectors', '3. Build a Complete Spider from A to Z', '4. Writing a Custom Pipeline - Store the Data in MongoDb', '5. Scraping Javascript Websites using Splash', '6. The Crawl Spider', '7. Avoid Getting Banned', '8. Scraping APIs(REST API) - Infinite Scroll Pagination', '9. Hosting spiders for free - Exclusive -']
# file_name []
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\1. Introduction - UPDATED -
# directory_name []
# file_name ['1. Intro to Web Scraping & Scrapy.mp4', '1. Intro to Web Scraping & Scrapy.vtt', '2. Setting up the Development Environment - Linux Users.mp4', '2. Setting up the Development Environment - Linux Users.vtt', '2.1 Python version 3.6.5 download link.html', '3. Setting up the Development Environment - Windows Users.mp4', '3. Setting up the Development Environment - Windows Users.vtt', '3.1 Python version 3.6.5 download link.html', '4. Hello World Scrapy.mp4', '4. Hello World Scrapy.vtt', '4.1 Goodreads website.html', '5. Frequently Asked Questions (Common errors).mp4', '5. Frequently Asked Questions (Common errors).vtt', '6. First section assignment.html', '7. Where to find all the code !.mp4', '7. Where to find all the code !.vtt']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\10. Writing data to Excel files
# directory_name []
# file_name ['1. Introduction to XlsxWriter.mp4', '1. Introduction to XlsxWriter.vtt', '2. Setting the Item class.mp4', '2. Setting the Item class.vtt', '3. Writing data to Excel files(Using a custom Pipeline).mp4', '3. Writing data to Excel files(Using a custom Pipeline).vtt', '4. Project source code.html', '5. Challenge for those who are adventurous.html']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\11. Scrapy POST requests
# directory_name []
# file_name ['1. Login to websites using FormRequest.mp4', '1. Login to websites using FormRequest.vtt', '2. XML Http Post Requests.mp4', '2. XML Http Post Requests.vtt', '2.1 Target website.html', '3. XML Http Post requests assignment.html', '4. Project source  code.html', '5. Code UPDATE XHR repeated data (Assignment).html']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\12. The Media Pipeline
# directory_name []
# file_name ['1. Media Pipelines.mp4', '1. Media Pipelines.vtt', '1.1 Media Pipeline documentation.html', '2. The Images Pipeline.mp4', '2. The Images Pipeline.vtt', '2.1 Target website.html', '3. Extending The Images Pipeline (Store images with custom names).mp4', '3. Extending The Images Pipeline (Store images with custom names).vtt', '4. Files Pipeline (Article).html', '5. Challenge (Files Pipeline).html', '6. Project source code.html']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\13. Paid and Free proxies with ScrapySplash
# directory_name []
# file_name ['1. Using Crawlera with Scrapy.mp4', '1. Using Crawlera with Scrapy.vtt', '2. Using Crawlera with Splash.mp4', '2. Using Crawlera with Splash.vtt', '3. Using Heroku as a Proxy (FREE).mp4', '3. Using Heroku as a Proxy (FREE).vtt', '4. Using FREE Proxies with the CrawlSpider.mp4', '4. Using FREE Proxies with the CrawlSpider.vtt', '5. Challenge.html', '6. Project source code.html']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\14. BONUS
# directory_name []
# file_name ['1. Files Pipeline.html', '2. Crawlera GIFT.html']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\2. XPath Selectors
# directory_name []
# file_name ['1. XPath Terminology.mp4', '1. XPath Terminology.vtt', '2. XPath Syntax.mp4', '2. XPath Syntax.vtt', '3. XPath Axes.mp4', '3. XPath Axes.vtt', '4. XPath Predicates.mp4', '4. XPath Predicates.vtt', '4.1 Cheat Sheet.pdf.pdf', '5. Second section assignment.html']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\3. Build a Complete Spider from A to Z
# directory_name []
# file_name ['1. Locating, Quotes, Authors and Tags.mp4', '1. Locating, Quotes, Authors and Tags.vtt', '10. Third section assignment.html', '2. Update Author is not loading .html', '3. Scrapy XPath Selectors.mp4', '3. Scrapy XPath Selectors.vtt', '4. Pagination.mp4', '4. Pagination.vtt', '5. Feed Exporters.mp4', '5. Feed Exporters.vtt', '6. Items and Item Loader.mp4', '6. Items and Item Loader.vtt', '7. Input and Output Processors.mp4', '7. Input and Output Processors.vtt', "8. Output isn't showing correctly.html", '9. FInal Touches.mp4', '9. FInal Touches.vtt']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\4. Writing a Custom Pipeline - Store the Data in MongoDb
# directory_name []
# file_name ['1. MongoDb Terminology.mp4', '1. MongoDb Terminology.vtt', '2. Setting Up MongoDb on Linux.mp4', '2. Setting Up MongoDb on Linux.vtt', '3. Setting Up MongoDb on Windows.mp4', '3. Setting Up MongoDb on Windows.vtt', '4. Writing the MongoDb Pipeline (UPDATED).mp4', '4. Writing the MongoDb Pipeline (UPDATED).vtt']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\5. Scraping Javascript Websites using Splash
# directory_name []
# file_name ['1. Why using Splash.mp4', '1. Why using Splash.vtt', '2. Setting up Splash on Linux.mp4', '2. Setting up Splash on Linux.vtt', '3. Writing Lua Scripts.mp4', '3. Writing Lua Scripts.vtt', '4. Splash Request.mp4', '4. Splash Request.vtt', '5. Dealing with Pagination.mp4', '5. Dealing with Pagination.vtt', '6. Sixth section Assignment.html']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\6. The Crawl Spider
# directory_name []
# file_name ['1. The Crawling Behaviour.mp4', '1. The Crawling Behaviour.vtt', '2. The Crawl Spider Simplified.mp4', '2. The Crawl Spider Simplified.vtt', '2.1 The Link Extractor Object.html', '2.2 The Rule Object.html', '3. Setting up the Rules.mp4', '3. Setting up the Rules.vtt', '4. Challenge Solution(Building the Parse Method).mp4', '4. Challenge Solution(Building the Parse Method).vtt', '5. Seventh section assignment.html']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\7. Avoid Getting Banned
# directory_name []
# file_name ['1. Technics Used by Websites Administrators to Prevent Web Scraping.mp4', '1. Technics Used by Websites Administrators to Prevent Web Scraping.vtt', '2. Web CrawlingScraping Best Practices.mp4', '2. Web CrawlingScraping Best Practices.vtt', '3. Custom Middleware (User Agent Rotator Middleware).mp4', '3. Custom Middleware (User Agent Rotator Middleware).vtt', '3.1 User Agents List.pdf.pdf']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\8. Scraping APIs(REST API) - Infinite Scroll Pagination
# directory_name []
# file_name ['1. Introduction.mp4', '1. Introduction.vtt', '10. Airbnb code UPDATE (Request Cookies) NEW.mp4', '10. Airbnb code UPDATE (Request Cookies) NEW.vtt', '10.1 demo_airbnb_new.zip.zip', '11. Another way to scrape Airbnb restaurant detail page.html', '2. REST API.mp4', '2. REST API.vtt', '3. Working With JSON Objects.mp4', '3. Working With JSON Objects.vtt', '3.1 employees.json.json', '3.2 test.py.py', '4. The Airbnb JSON Object.mp4', '4. The Airbnb JSON Object.vtt', '5. Hidden XHR.html', '6. Airbnb Spider.mp4', '6. Airbnb Spider.vtt', '6.1 Hidden detail page url.html', '7. IMPORTANT NOTE.html', '8. Infinite Scroll Pagination.mp4', '8. Infinite Scroll Pagination.vtt', '9. Spider Arguments.mp4', '9. Spider Arguments.vtt']
#
# directory_path \Users\User\Desktop\Web scraping\Modern Web Scraping with Python using Scrapy and Splash\9. Hosting spiders for free - Exclusive -
# directory_name []
# file_name ['1. Deploy spiders to ScrapingHub cloud.mp4', '1. Deploy spiders to ScrapingHub cloud.vtt', '1.1 Scrapy cloud.html', '2. Deploy spiders locally.mp4', '2. Deploy spiders locally.vtt', '3. Deploy spiders to Heroku.mp4', '3. Deploy spiders to Heroku.vtt', '3.1 .gitignore.html', '4. The MLab add-on.mp4', '4. The MLab add-on.vtt', '5. Execute spiders periodically.mp4', '5. Execute spiders periodically.vtt', '5.1 APScheduler documentation.html', '5.2 add_job().pdf.pdf', '6. Prevent storing duplicated data.mp4', '6. Prevent storing duplicated data.vtt', '7. Deploy Splash to Heroku.mp4', '7. Deploy Splash to Heroku.vtt', '8. Project source code.html']
#
# directory_path \Users\User\Desktop\Web scraping\python-3.8.3rc1-docs-pdf-a4
# directory_name ['docs-pdf']
# file_name []
#
# directory_path \Users\User\Desktop\Web scraping\python-3.8.3rc1-docs-pdf-a4\docs-pdf
# directory_name []
# file_name ['c-api.pdf', 'distributing.pdf', 'extending.pdf', 'faq.pdf', 'howto-argparse.pdf', 'howto-clinic.pdf', 'howto-cporting.pdf', 'howto-curses.pdf', 'howto-descriptor.pdf', 'howto-functional.pdf', 'howto-instrumentation.pdf', 'howto-ipaddress.pdf', 'howto-logging-cookbook.pdf', 'howto-logging.pdf', 'howto-pyporting.pdf', 'howto-regex.pdf', 'howto-sockets.pdf', 'howto-sorting.pdf', 'howto-unicode.pdf', 'howto-urllib2.pdf', 'installing.pdf', 'library.pdf', 'reference.pdf', 'tutorial.pdf', 'using.pdf', 'whatsnew.pdf']
#
# directory_path \Users\User\Desktop\Web scraping\Web Scraping for Beginners with Python Scrapy BS4
# directory_name ['1. Getting Started', '2. Installing required software', '3. Basic Web Scraping  using BeautifulSoup and Python', '4. Basic Web Scraping using Scrapy and Python', '5. HTML  Quick Refresher']
# file_name []
#
# directory_path \Users\User\Desktop\Web scraping\Web Scraping for Beginners with Python Scrapy BS4\1. Getting Started
# directory_name []
# file_name ['1. Introduction.mp4', '1. Introduction.vtt', '2. What is Web Scraping.mp4', '2. What is Web Scraping.vtt', '3. Tools for web scraping.mp4', '3. Tools for web scraping.vtt', '4. How the internet works.mp4', '4. How the internet works.vtt', '5. What is HTTP.mp4', '5. What is HTTP.vtt', '6. What are text editors.mp4', '6. What are text editors.vtt', '7. What we will scrape.mp4', '7. What we will scrape.vtt', '8. Inspecting Elements.mp4', '8. Inspecting Elements.vtt']
#
# directory_path \Users\User\Desktop\Web scraping\Web Scraping for Beginners with Python Scrapy BS4\2. Installing required software
# directory_name []
# file_name ['1. Installing Visual Studio Code.mp4', '1. Installing Visual Studio Code.vtt', '2. Updating Python and Pip.mp4', '2. Updating Python and Pip.vtt', '3. Installing virtual environment.mp4', '3. Installing virtual environment.vtt', '4. Creating and activating a virtual environment.mp4', '4. Creating and activating a virtual environment.vtt', '5. Installing BeautifulSoup.mp4', '5. Installing BeautifulSoup.vtt', '6. Installing Scrapy.mp4', '6. Installing Scrapy.vtt']
#
# directory_path \Users\User\Desktop\Web scraping\Web Scraping for Beginners with Python Scrapy BS4\3. Basic Web Scraping  using BeautifulSoup and Python
# directory_name []
# file_name ['1. Building a web scraping script - part 1.mp4', '1. Building a web scraping script - part 1.vtt', '2. Building a web scraping script - part 2.mp4', '2. Building a web scraping script - part 2.vtt', '3. Prototyping the script  part 1.mp4', '3. Prototyping the script  part 1.vtt', '4. Prototyping the script  part 2.mp4', '4. Prototyping the script  part 2.vtt', '5. Prototyping the script  part 3.mp4', '5. Prototyping the script  part 3.vtt', '6. Prototyping the script  part 4.mp4', '6. Prototyping the script  part 4.vtt', '7. Prototyping the script  part 5.mp4', '7. Prototyping the script  part 5.vtt', '8. Testing Running  Saving  Scraped data to file.mp4', '8. Testing Running  Saving  Scraped data to file.vtt']
#
# directory_path \Users\User\Desktop\Web scraping\Web Scraping for Beginners with Python Scrapy BS4\4. Basic Web Scraping using Scrapy and Python
# directory_name []
# file_name ['1. Creating a Scrapy project.mp4', '1. Creating a Scrapy project.vtt', '2. Components of a Scrapy Project.mp4', '2. Components of a Scrapy Project.vtt', '3. Scrapy Architecture.mp4', '3. Scrapy Architecture.vtt', '4. Creating a Spider  part 1.mp4', '4. Creating a Spider  part 1.vtt', '5. Creating a Spider  part 2.mp4', '5. Creating a Spider  part 2.vtt', '6. Scraping data  with  scrapy shell  Part 1.mp4', '6. Scraping data  with  scrapy shell  Part 1.vtt', '7. Scraping data  with  scrapy shell  Part 2.mp4', '7. Scraping data  with  scrapy shell  Part 2.vtt', '8. Running the spider and saving scraped data.mp4', '8. Running the spider and saving scraped data.vtt']
#
# directory_path \Users\User\Desktop\Web scraping\Web Scraping for Beginners with Python Scrapy BS4\5. HTML  Quick Refresher
# directory_name []
# file_name ['1. What is HTML.mp4', '1. What is HTML.vtt', '10. HTML Heading element.mp4', '10. HTML Heading element.vtt', '11. HTML Paragraph element.mp4', '11. HTML Paragraph element.vtt', '12. HTML block level elements.mp4', '12. HTML block level elements.vtt', '13. HTML Div element.mp4', '13. HTML Div element.vtt', '2. Anatomy of HTML Elements.mp4', '2. Anatomy of HTML Elements.vtt', '3. Nesting elements.mp4', '3. Nesting elements.vtt', '4. HTML Documents.mp4', '4. HTML Documents.vtt', '5. HTML Element Hierarchy.mp4', '5. HTML Element Hierarchy.vtt', '6. Empty HTML elements.mp4', '6. Empty HTML elements.vtt', '7. HTML Attributes.mp4', '7. HTML Attributes.vtt', '8. HTML Id attribute.mp4', '8. HTML Id attribute.vtt', '9. HTML Class attribute.mp4', '9. HTML Class attribute.vtt']

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\User\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'LAPTOP-57JFPPQN',
#         'COMSPEC': 'C:\\windows\\system32\\cmd.exe',
#         'CONDA_DEFAULT_ENV': 'base',
#         'CONDA_EXE': 'C:\\Users\\User\\anaconda3\\Scripts\\conda.exe',
#         'CONDA_PROMPT_MODIFIER': '(base) ',
#         'CONDA_PYTHON_EXE': 'C:\\Users\\User\\anaconda3\\python.exe',
#         'CONDA_ROOT': 'C:\\Users\\User\\anaconda3',
#         'CONDA_SHLVL': '1',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\User',
#         'KOLIBRI_GUI_LANG': 'en',
#         'KOLIBRI_SCRIPT_DIR': 'C:\\Python34\\Scripts',
#         'LOCALAPPDATA': 'C:\\Users\\User\\AppData\\Local',
#         'LOGONSERVER': '\\\\LAPTOP-57JFPPQN',
#         'NUMBER_OF_PROCESSORS': '8',
#         'ONEDRIVE': 'C:\\Users\\User\\OneDrive',
#         'ONLINESERVICES': 'Online Services',
#         'OS': 'Windows_NT',
#         'PATH': 'C:\\Users\\User\\anaconda3;C:\\Users\\User\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\User\\anaconda3\\Library\\usr\\bin;C:\\Users\\User\\anaconda3\\Library\\bin;C:\\Users\\User\\anaconda3\\Scripts;C:\\Users\\User\\anaconda3\\bin;C:\\Users\\User\\anaconda3\\condabin;C:\\Users\\User\\anaconda3;C:\\Users\\User\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\User\\anaconda3\\Library\\usr\\bin;C:\\Users\\User\\anaconda3\\Library\\bin;C:\\Users\\User\\anaconda3\\Scripts;C:\\windows\\system32;C:\\windows;C:\\windows\\System32\\Wbem;C:\\windows\\System32\\WindowsPowerShell\\v1.0;C:\\windows\\System32\\OpenSSH;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python38\\Scripts;C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python38;C:\\Python34\\Scripts;C:\\windows\\system32;C:\\windows;C:\\windows\\System32\\Wbem;C:\\windows\\System32\\WindowsPowerShell\\v1.0;C:\\windows\\System32\\OpenSSH;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\User\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\User\\AppData\\Local\\Programs\\Microsoft VS Code\\bin',
#         'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#         'PLATFORMCODE': 'KV',
#         'PROCESSOR_ARCHITECTURE': 'AMD64',
#         'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 158 Stepping 10, GenuineIntel',
#         'PROCESSOR_LEVEL': '6',
#         'PROCESSOR_REVISION': '9e0a',
#         'PROGRAMDATA': 'C:\\ProgramData',
#         'PROGRAMFILES': 'C:\\Program Files',
#         'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#         'PROGRAMW6432': 'C:\\Program Files',
#         'PROMPT': '(base) $P$G',
#         'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\windows\\system32\\WindowsPowerShell\\v1.0\\Modules',
#         'PUBLIC': 'C:\\Users\\Public',
#         'REGIONCODE': 'APJ',
#         'SESSIONNAME': 'Console',
#         'SYSTEMDRIVE': 'C:',
#         'SYSTEMROOT': 'C:\\windows',
#         'TEMP': 'C:\\Users\\User\\AppData\\Local\\Temp',
#         'TMP': 'C:\\Users\\User\\AppData\\Local\\Temp',
#         'USERDOMAIN': 'LAPTOP-57JFPPQN',
#         'USERDOMAIN_ROAMINGPROFILE': 'LAPTOP-57JFPPQN',
#         'USERNAME': 'User',
#         'USERPROFILE': 'C:\\Users\\User',
#         'WINDIR': 'C:\\windows',
#         'CONDA_PREFIX': 'C:\\Users\\User\\anaconda3',
#         'KERNEL_LAUNCH_TIMEOUT': '40',
#         'JPY_INTERRUPT_EVENT': '2608',
#         'IPY_INTERRUPT_EVENT': '2608',
#         'JPY_PARENT_PID': '2996',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://ipykernel.pylab.backend_inline'}

# %%
print(dir(os.environ)) # methods in the os.environ directory
# Out:
# ['_MutableMapping__marker', '__abstractmethods__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__setitem__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_data', 'clear', 'copy', 'decodekey', 'decodevalue', 'encodekey', 'encodevalue', 'get', 'items', 'keys', 'pop', 'popitem', 'putenv', 'setdefault', 'unsetenv', 'update', 'values']

# %%
# Further reading on os.environ
# Out:
# None

# %%
# To create filepath from two different directories, file

file_path = os.path.join(r'\Users\User\Desktop', 'test_os_path_join') # This way we avoid the \ problem of concatenation approach

# %%
print(file_path) # backslash successfully added
# Out:
# \Users\User\Desktop\test_os_path_join

# %% [markdown]
# - To test other directories in os.path

# %%
os.path.basename(file_path) # To print basename
# Out:
# 'test_os_path_join'

# %%
os.path.dirname(file_path) # To print directory name
# Out:
# '\\Users\\User\\Desktop'

# %%
os.path.split(file_path)  # To split directory and basename
# Out:
# ('\\Users\\User\\Desktop', 'test_os_path_join')

# %%
os.path.exists(file_path) # Shows that file does not exist in the directory
# Out:
# False

# %%
os.path.isfile(file_path) # if it is a file
# Out:
# False

# %%
os.path.isdir(file_path) # if it is a directory
# Out:
# False

# %%
os.path.splitext(file_path) # To split file route and extension. Empty string means no extension
# Out:
# ('\\Users\\User\\Desktop\\test_os_path_join', '')
