# %% [markdown]
# Visual Design in web development is a broad topic. It combines typography, color theory, graphics, animation, and page layout to help deliver a site's message. The definition of good design is a well-discussed subject, with many books on the theme.
#
# At a basic level, most web content provides a user with information. The visual design of the page can influence its presentation and a user's experience. In web development, HTML gives structure and semantics to a page's content, and CSS controls the layout and appearance of it.

# %% [raw]
# - Text align
#
# text-align: center/right/left/justify;
# width: ;
# height: ;
#
# - To bolden a text. Use "strong" tags around the text. With this, CSS applies the font-weight: bold;
# - To under a text. Use "u" tags around the text. With this, CSS applies text-decoration: underline;
# - To italicize text. Use "em" tags around the text. With this, CSS applies font-style: italics;
# - To strike-through a text. Use "s" tags around the text. With this, CSS applies text-decoration: line-through;
# - To draw a horizontal line. Use "hr" tag. <hr> "hr" tag is self-enclosing. It should come after the text to be underlined.
# - rgba stands for red, green, blue and alpha (opacity). rgb (range 0-255) alpha (range 0-1)
#
# - To add one or more shadows to an element. We can apply multiple shadows by separating the properties of the box-shadow by a comma,
#
# box-shadow: offset-x offset-y blur-radius spread-radius color # blur-radius and spread-radius are optional
# - To make an element opaque. Use the "opacity" property
# - To change the size of text. Use "font-size" property
# - To change the vertical space each line of text / element get. Use "line-height"
# - To change the color of an element when user hover around it. To make anchor element blue when user hover on it. a:hover psedoclass is used as shown below:
#
# <style>
#     a:hover {
#         color: red;
#     }
# </style>
#
# - Changing an elements relative position. by using "position: relative" and CSS offset properties like right/left/top/bottom
#
# - To make object stay in place without any dependence on element before it or above it in terms of offset. This effect is usually seen as the object stays in place upon scrolling.
#
# - To float an element within its container. Use the "float" property either to the left/right.
#
# - How to determine an element that would be stack ontop of another. Use "z-index". It has to be a whole number. The higher the number the higher up the element on the stack. Elements also get to overlap using position property. The following can be assumed by the position property. Using position: absolute | relative | fixed | sticky.
#
# - To center a block element. We can use "margin: auto". This method can also be applied on image as well. Image is primarily an inline element. But can be changed to block by setting "display: block"
#
# - Colors have several features such as hue, saturation and lightness. "Hue" is the position of color in a spectrum of colors. Using the color-wheel model. Hue has a value between 0 and 360. "Saturation" is the amount of gray in a color. A fully saturated color has no gray in it. 100% = Fully-saturated = No-gray; 0% = No-saturation = 100% gray. "Lightness" is the amount of black and white in a color. 0% = black; 50% = Normal color; 100% = white
#
# - USing CSS3, this color features can be gotten by hsl() method
#
# - The hsl() method is useful for tinting and shading our color hue. This is achieved by tweaking the "saturation" and "lightness".
#
# - To have color transitions. Use "background: linear-gradient(degree, color1, color2, ...)". The "degree" attribute determine the direction of transition of the colors. If 90deg, color transition moves horizontally from left to right. If 45deg, color transition moves diagonally.
#
# - To repeat transitions over the width of the element. Use "background: repeating-linear-gradient(deg, color1 color-stop1(px),
# color2 color-stop2(px)....)"
#
# - Create a subtle pattern using the url() function. This allows url-link of the image to be passed to it. This creates a subtle background that makes info on the foreground visible.
#
# - To change the scale of an element. Use the "transform:  scale(n)". This means the size would be increased by "n" size
#
# - To change the size upon hovering. ":hover" pseudoclass is used with "transform:  scale(n)" nested inside it
#
# - ::before and ::after pseudo-elements can be used to in addition to class to add sth before and after an element
#
# - To animate an element. Two important concepts are key and known as "animation properties" and "@keyframes" rules. The animation properties are used to create the animation while the @keyframe rules set the behavior during course of animation. Animation properties are set within the style elements as "id" and @keyframe rules created also within the style elements. Animation properties are 8 in numbers but two are taken into consideration (animation-name and animation-duration).
#
# <style>
#     #anim {
#         animation-name: colorful;
#         animation-duration: 3s;
#     }
#     @keyframes colorful {
#         0% {
#         background-color: blue;
#         }
#         100% {
#         background-color: yellow;
#         }
#     }
# </style>
#
# - :hover state can also be used to change the animation state of an element. The implementation is shown below:
#
# <style>
#     :hover {
#         animation-name: ;
#         animation-duration: ;   # The animation-name is subsequently used in @keyframes rule.
#         animation-fill-mode: forwards;  # animation-fill-mode keeps the @keyframes rule highlighted upon hovering
#                                         # without going off when the duration elapses
#     }
# </style>
#
# - "animation-iteration-count" determines the number of times one loops through the animation. If one wants it infinite times. It can be set to "infinite".
#
# - "animation-timing-function". This determines how an animation changes over its duration. This kind be seen in the light of acceleration/ deceleration of a car in moving from point A to point B. It takes either of 4 attributes "ease| ease-in | ease-out| linear"
# - Another way to set "animation-timing-function" without using the above 4 keywords is using the cubic-bezier function.
# It has 4 parameters namely p0, p1, p2, p3. p0 and p3 are (0,0) and (1,1) respectively used for denoting the endpoints(start-to-finish line). However, p1 and p2 can assume any combination of (x,y) coordinates with values of x and y between 0 and 1.
# Therefore. it is represented as cubic-bezier(p1, p2). cubic-bezier(x1, y1, x2, y2).
#
# -
