# %% [markdown]
# Web accessibility has tto do with making web content and user interface available to a broad audience. Especially for people with cognitive, auditory and visual disabilities.
#
# 3 concepts that are crucially important for these are:
# - Have well-structured codes with appropriate mark-up
# - Ensure text alternatives exist for non-text and visual content
# - Create easily navigable webpage that is keyboard friendly
#
# Having accessible web content is an ongoing challenge. A great resource for your projects going forward is the W3 Consortium's Web Content Accessibility Guidelines (WCAG). They set the international standard for accessibility and provide a number of criteria you can use to check your work.

# %% [raw]
# - Using alt attribute in image tag to make web content very accessible to people with visual disabilities that depend on screen readers
#
# - Set alt="" when using decorative image. Or perhaps when the image is part of group with a caption or when the image description is redundant.
#
# - h1 to h6 should be properly used to show correct hierarchical relationships amongst the content of a webpage
#
# - HTML5 added new elements to aid developers while also improving accessibility features. Example are: main, header, footer, nav, article, and section, among others.
#
# - "main" tag is used to sorround the central topic of a webpage. It has an embedded landmark feature that assisitive technology can use to navigate to the main content. Example, "Jump to Main Content" link is automatically given to assisitive devices if a main tag is featured in the markup language of the webpage.
#
# - Distinction between div, section and article elements
#
# <div>: groups unrelated content
# <section>: groups related content
# <article>: groups independent and self-contained content
#
# - "header" tag is used for wrapping introductory info and navigation links of the parent tag and works well around content that is repeated on multiple pages. "header" shares embedded landmark feature we saw with "main" allowing assistive technologies to navigate to the content.
#
# N.B: It is important to note that the "header" is meant for use in the "body" tag. This is different than the "head" element which contains the page's title and meta information
#
# - "nav" tag is a newly created element in HTML5. It also has embedded landmark features that increase accessibility. It is meant to wrap around the main navigation links of a webpage. If there are repeated links on the bottom of the page. "footer" header is sufficient for this purpose.
#
# - HTML5s "audio" element gives semantic meaning to a code to increase accessibility. it is wrapped aound sound/ audio stream content. It helps people with auditory disabilities. This can be done by adding text alternatives or link to audio transcript.
# N.B: The audio element supports "controls" attribute which helps to create play/plause and other controls needed for interacting with the audio components. The code is shown below:
#
# <audio id="meowClip" controls>
#     <source src="audio/meow.mp3" type="audio/mpeg">
#     <source src="audio/meow.ogg" type="audio/ogg">
# </audio>
#
# - HTML5 "figure" and "figcaption" these are used to wrap visual representations (diagrams/images/charts) and their captions. It has a combined benefit of semantically grouping related contents and adding text alternatives. For data visuals, the caption should be used to detail the trends/conclusions of the chart.
# N.B: <figcaption> element is a child of <figure> element
#
# - <label> tag wraps texts for specific form control usually name or label for a choice. The "for" attribute of a label tag explicitly associates the form to the form controls and used by screen readers.
# N.B: The value of the for attribute must be the same as the value of the id attribute of the form control.
#
# - <fieldset> element is used for grouping radio-buttons. It uses the <legend> element to provide a description of the grouping
#
# - To add a date input
#
# <label for="date-input">Description of date input</label>
# <input id="date-input" type="date" name="date-input">
#
# - HTML5 introduces the <time> element with a "datetime" attribute for standardizing
# - <sup>th</sup> makes "th" a superscript
#
# - CSS rules that hide elements away from visual users. It can be made only accessible to screen readers
#
# .sr-only {
#     position: absolute;
#     left: -10000px;
#     width: 1px;
#     height: 1px;
#     top: auto;
#     overflow: hidden;
#     }
#
# The following below will not do the same as above:
#
# # display: None; visibility: hidden; Hides content for everyone including screen reader users
# # Zero values for pixel sizes, such as width: 0px; height: 0px; removes element from flow of a document. This will make sure that screen readers ignore it.
#
# - Low contrast between foreground and background makes text difficult to read. Sufficient contrast is necessary to make text easy to read. "Sufficient contrast" is a phrase defined by the "Web content accessibility guideline" to mean a contrast ratio of at least 4.5 to 1. This is usually calculated by processing the relative luminance values of the two colors. There are online programs that can help to compute the contrast ratio of a webpage.
#
# - The contrast ratio can be tweaked by using hsl() method to set the color we want. Shading and tinting are usually done by tweaking the lightness value.
#
# - To make link text accessible, descriptive names should be used so as to make screen-reader users make good sense of the links on the webpage. Populating all links with link texts like "Click here" and "Read more" do not help the screen-reader users make lots of sense with the information on the link.
#
# - HTML "accesskey" attribute is used to make a webpage element easily accessible esp. for people using only keyboard to interact with the computer. This atrribute can be used by any element. However, it is particularly useful for intercative elements like links, radio-buttons and form controls.
#
# - "tabindex" can be used to bring keyboard focus to an element. Interactive elements such as links and form controls usually are tab-focused and this is done inline with the position of the elements on the page. This keyboard focus can be applied to other elements like "span, div and p" elements by setting their "tabindex=0".
#
# - "tabindex" can also be used first to set the other
