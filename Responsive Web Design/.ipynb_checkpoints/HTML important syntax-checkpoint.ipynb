# %% [raw]
# - main heading tags
#  <h1></h1>
#
# - heading 2 tags
#  <h2></h2>
#
# - heading 3 tags
#  <h3></h3>
#
# - To add text to paragraphs
#  <p></p>
#
# - This is use to comment out HTML tags
#  <!-- -->
#
# - This shows the main content of a webpage
#  <main></main>
#
# - To have an image on the webpage
#  <img src="url-link" alt="This describes the content of the image">
#
# - To access content outside of a webpage
#  <a href="url-link outside webpage"> anchor text</a>
#
# - To access a content inside of a webpage
#
# <a href="#footer">Jump to the bottom of the page</a> # Specify id attribute to the footer tag
# <footer id="footer"></footer>
#
# - Nesting anchor element within a paragraph element
#
# <p>
#     <a href="url link"> anchor text to be clicked upon</a> Text besides the anchor text
# </p>
#
# - Create a dead link by setting href="#"
#
# <a href="#"> anchor text to be clicked upon </a>
#
# - We can use image source as a link
#
# <a>
#     <img src="url-link of image" alt="Text describing image">
# </a>
#
# - Creating an unordered list
#
# <ul>
#     <li> ... </li> # This is used to encapsulate each bulleted word
#     <li> ... </li> # The number of <li></li> tags depend on then number of listed words
# </ul>
#
# - Create an input text
#
# <input type="text"> # This is self-enclosing tag just like the image element
#
# - Adding a placeholder text (This is the text in the input tab before the USER enter a text)
#
# <input type="text" placeholder="text in the input">
#
# - Create a form element
#
# <form action="url-to-send-the-form"></form>
#
# - Create a button action to submit form
#
# <button type="submit"> Text on the submit button </button>
#
# - Make sure a form is filled before it can be submitted
#
# <input type="text" required>
#
# - Create radio buttons. It works by selecting an item in a group while deselecting others. Each input element is nested within
# - a label element. For radio buttons in the same group, "name" attribute is made the same for the different radio button input
#
# <label for="indoor">
#     <input id="indoor" type="radio" name="indoor-outdoor">Text for 1st radio button
# </label>
#
# <label for="outdoor">
#     <input id="outdoor" type="radio" name="indoor-outdoor">Text for 2nd radio button
# </label>
#
# - Create checkbox button # Just like radio-buttons, Checkboxes in the same group can be identified with the same "name" attribute
#
# <label for="loving">
#     <input id="loving" type="checkbox" name="personality"> Text in front of checkbox
# </label>
#
# - For the above radio-buttons and checkbox, if they are selected and form submitted, the "name" attribute would be set to ON.
# - However, if we want the name attribute to be set to a meaningful word, then the "value" attribute is set to the meaningful word
#
# <label for="loving">
#     <input id="loving" value="attribute" type="checkbox" name="personality"> Text in front of checkbox
# </label
#
# - Add check to the input element to check radio-buttons and checkbox by default
#
# <input type="radio" name="test-name" checked>
#
# - Any markup info about the page goes into the head element while content of the page goes into the body elements
# - metadata elements such as link, meta, style, and title are nested into the head element
